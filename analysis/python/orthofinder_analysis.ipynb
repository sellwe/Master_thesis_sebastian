# %% [markdown]
# OrthoFinder Analysis

# %% [markdown]
# load packages

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Load orthofinder dataset for C_mac created in R

# %%
ortho_c_mac = pd.read_csv("C:/Users/Sebas/OneDrive/Dokument/Master courses/MASTER THESIS/R project-Master Thesis/c_mac_orthologs.csv", index_col=0)
ortho_c_mac
# Out:
#                       OG Gene Tree Parent Clade  \
# HOG
# N0.HOG0000000  OG0000000                     n0
# N0.HOG0000001  OG0000001                     n3
# N0.HOG0000001  OG0000001                     n3
# N0.HOG0000001  OG0000001                     n3
# N0.HOG0000002  OG0000001                   n117
# ...                  ...                    ...
# N0.HOG0029133  OG0028480                      -
# N0.HOG0029134  OG0028481                      -
# N0.HOG0029135  OG0028482                      -
# N0.HOG0029136  OG0028483                      -
# N0.HOG0029137  OG0028484                      -
#
#               C_maculatus_filtered_proteinfasta_TE_filtered transcript_id
# HOG
# N0.HOG0000000                                           NaN           NaN
# N0.HOG0000001                       C_maculatus_g21530.t1_1     g21530.t1
# N0.HOG0000001                       C_maculatus_g10168.t1_1     g10168.t1
# N0.HOG0000001                        C_maculatus_g2059.t1_1      g2059.t1
# ...
