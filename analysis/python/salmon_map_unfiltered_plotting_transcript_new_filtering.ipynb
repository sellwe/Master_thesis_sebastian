# %% [markdown]
# For the unfiltered, consistent annotations, using the whole genome decoys.

# %% [markdown]
# Load packages

# %%
import numpy as np
import pandas as pd
import plotly.express as px

from sklearn.decomposition import PCA

# %% [markdown]
# PCA

# %% [markdown]
# Load the datasets created in R

# %%
norm_counts = pd.read_csv("C:/Users/Sebas/OneDrive/Dokument/Master courses/MASTER THESIS/R project-Master Thesis/salmon_mapping_normalized_counts_transcript_consistent_new_filtering_genotype_controlled_age_rank_fixed.csv", index_col=0)
norm_counts
# Out:
#            ERR12356072  ERR12383247  ERR12383248  ERR12383249  ERR12383250  \
# g2.t1         7.881771     8.058656     8.200582     8.989201     8.483403
# g3.t1         7.104422     6.979309     7.505145     7.205331     7.862185
# g4.t1         7.534024     7.541877     7.493801     7.001077     7.034639
# g5.t1         4.705132     5.077636     4.705132     5.572966     5.331813
# g6.t1         8.597134     9.003656     8.404115     8.018723     8.359932
# ...                ...          ...          ...          ...          ...
# g34843.t1     5.568589     5.979236     6.108379     6.139920     5.703349
# g34884.t1     4.705132     4.946457     4.705132     4.705132     4.705132
# g34922.t1     5.300410     5.275054     5.259485     5.349363     5.287871
# g35167.t1     5.335532     5.399010     5.971149     6.040235     5.529231
# g35420.t1     4.921147     4.951358     4.705132     4.705132     4.705132
#
#            ERR12383251  ERR12383252  ERR12383253  ERR12383254  ERR12383255  \
# g2.t1         9.207270     7.789775     8.047834     8.115469     8.778877
# g3.t1         7.617001     6.814318     7.493388     7.168586     7.414131
# g4.t1         6.998020     7.467329     7.343332     7.623867     6.989608
# g5.t1         5.399441     4.891187     4.705132     5.356088     6.052900
# g6.t1         8.217918     8.956325     8.652484     8.860414     8.413296
# ...                ...          ...          ...          ...          ...
# g34843.t1     6.381351     5.816248     5.593577     5.767815     6.210711
# g34884.t1     5.333187     4.944951     4.705132     4.705132     4.705132
# g34922.t1     5.794722     5.344353     5.041779     5.331760     4.705132
# g35167.t1     6.069947     5.604051     5.694882     6.264427     5.234190
# g35420.t1     4.705132     4.960152     4.705132     4.705132     5.274777
#
#            ...  ERR12383308  ERR12383309  ERR12383310  ERR12383311  \
# g2.t1      ...     8.467024     8.155217     8.394621     7.710989
# g3.t1      ...     6.687924     7.029923     6.561583     5.951002
# g4.t1      ...     7.288582     7.315381     7.316950     7.502316
# g5.t1      ...     4.705132     4.705132     4.705132     4.999428
# g6.t1      ...     8.218780     8.231387     8.497639     8.768974
# ...        ...          ...          ...          ...          ...
# g34843.t1  ...     5.385320     4.934162     5.212956     5.875921
# g34884.t1  ...     5.671103     5.393559     4.951411     4.967682
# g34922.t1  ...     6.597373     5.621284     5.379683     5.375077
# g35167.t1  ...     7.441429     5.600768     5.494096     5.582972
# g35420.t1  ...     5.352197     5.048081     4.971039     4.705132
#
#            ERR12383312  ERR12383313  ERR12383314  ERR12383315  ERR12383316  \
# g2.t1         7.845979     8.337393     7.810269     8.165106     8.243547
# g3.t1         6.297211     6.402428     6.475258     7.676542     7.843207
# g4.t1         7.526480     7.383176     7.403942     6.984740     7.056760
# g5.t1         4.705132     4.880468     4.705132     5.898931     5.443409
# g6.t1         9.001573     9.025714     8.967964     8.287835     7.997991
# ...                ...          ...          ...          ...          ...
# g34843.t1     5.120709     5.130703     5.592102     6.425403     5.974385
# g34884.t1     4.886300     5.200379     4.705132     5.241201     4.982608
# g34922.t1     5.083233     5.297305     5.320336     5.973553     4.705132
# g35167.t1     5.489341     5.284240     5.135388     7.469274     6.192084
# g35420.t1     4.705132     4.705132     5.062203     5.277201     5.128011
#
#            ERR12383317
# g2.t1         9.002930
# g3.t1         7.471256
# g4.t1         6.423256
# g5.t1         4.705132
# g6.t1         7.895544
# ...                ...
# g34843.t1     6.018597
# g34884.t1     5.315526
# g34922.t1     5.258290
# g35167.t1     6.607969
# g35420.t1     4.705132
#
# [17574 rows x 70 columns]

# %%
#Metadata
metadata = pd.read_csv("C:/Users/Sebas/OneDrive/Dokument/Master courses/MASTER THESIS/R project-Master Thesis/dominance_meta_corrected_outlier_corrected.csv")

#make sure order matches norm_counts
metadata = metadata.set_index('Run')
metadata = metadata.reindex(norm_counts.columns)
# Now Run is the index, and metadata is aligned with counts
print("Metadata index (samples):", metadata.index[:5].tolist())
print("Counts columns:", norm_counts.columns[:5].tolist())
print("Match?", all(metadata.index == norm_counts.columns))
metadata
# Out:
# Metadata index (samples): ['ERR12356072', 'ERR12383247', 'ERR12383248', 'ERR12383249', 'ERR12383250']
# Counts columns: ['ERR12356072', 'ERR12383247', 'ERR12383248', 'ERR12383249', 'ERR12383250']
# Match? True
#                    Bases  BioProject       BioSample   Experiment  \
# ERR12356072  21027960416  PRJEB70958  SAMEA114860228  ERX11733017
# ERR12383247  14794943760  PRJEB70958  SAMEA114860213  ERX11759665
# ERR12383248  15610248328  PRJEB70958  SAMEA114860214  ERX11759666
# ERR12383249   9412089720  PRJEB70958  SAMEA114860215  ERX11759667
# ERR12383250   9959631122  PRJEB70958  SAMEA114860216  ERX11759668
# ...                  ...         ...             ...          ...
# ERR12383313  27406244206  PRJEB70958  SAMEA114860279  ERX11759731
# ERR12383314  13458064958  PRJEB70958  SAMEA114860280  ERX11759732
# ERR12383315  11890141660  PRJEB70958  SAMEA114860281  ERX11759733
# ERR12383316  13692674262  PRJEB70958  SAMEA114860282  ERX11759734
# ERR12383317  14658478416  PRJEB70958  SAMEA114860283  ERX11759735
#
#                                sample_name_incorrect         TF ID Sample ID  \
# ERR12356072  Sample 1 males genotype BA heterozygote  TF2581-10-e3     10e 3
# ERR12383247  Sample 1 females genotype AA homozygote     TF2581-11        11
# ERR12383248  Sample 2 females genotype AA homozygote     TF2581-12        12
# ERR12383249  Sample 3 females genotype AA homozygote     TF2581-13        13
# ERR12383250    Sample 1 males genotype AA homozygote  TF2581-14-e2     14e 2
# ...                                              ...           ...       ...
# ERR12383313  Sample 1 females genotype FF homozygote     TF2581-71        71
# ERR12383314  Sample 2 females genotype FF homozygote     TF2581-72        72
# ERR12383315  Sample 3 females genotype FF homozygote      TF2581-7         7
# ERR12383316    Sample 1 males genotype FF homozygote      TF2581-8         8
# ERR12383317    Sample 2 males genotype FF homozygote     TF2581-9e        9e
#
#                              Cross  Family Sex Reciprocal Genotype  \
# ERR12356072  13:20 (M) + 42:13 (F)  2,3,4,   F                  AB
# ERR12383247  13:20 (M) + 42:13 (F)  2,3,4,   F                  AB
# ERR12383248  13:20 (M) + 42:13 (F)  2,3,4,   F                  AB
# ERR12383249  42:13 (M) + 13:20 (F)   1,4,8   M                  BA
# ERR12383250  42:13 (M) + 13:20 (F)   1,4,8   M                  BA
# ...                            ...     ...  ..                 ...
# ERR12383313            4:18 + 4:18   2,6,9   F                  FF
# ERR12383314            4:18 + 4:18   2,6,9   F                  FF
# ERR12383315  13:20 (M) + 42:13 (F)  2,3,4,   M                  AB
# ERR12383316  13:20 (M) + 42:13 (F)  2,3,4,   M                  AB
# ERR12383317  13:20 (M) + 42:13 (F)  2,3,4,   M                  AB
#
#                     Genotype  Pairwise Cross  \
# ERR12356072  AB Heterozygote               1
# ERR12383247  AB Heterozygote               1
# ERR12383248  AB Heterozygote               1
# ERR12383249  AB Heterozygote               1
# ERR12383250  AB Heterozygote               1
# ...                      ...             ...
# ERR12383313    FF Homozygote               3
# ERR12383314    FF Homozygote               3
# ERR12383315  AB Heterozygote               1
# ERR12383316  AB Heterozygote               1
# ERR12383317  AB Heterozygote               1
#
#                              original_fastq_name_R1  \
# ERR12356072  TF-2581-10-e3_S67_L001_R1_001.fastq.gz
# ERR12383247      TF-2581-11_S9_L001_R1_001.fastq.gz
# ERR12383248     TF-2581-12_S10_L001_R1_001.fastq.gz
# ERR12383249     TF-2581-13_S11_L001_R1_001.fastq.gz
# ERR12383250  TF-2581-14-e2_S68_L001_R1_001.fastq.gz
# ...                                             ...
# ERR12383313     TF-2581-71_S59_L001_R1_001.fastq.gz
# ERR12383314     TF-2581-72_S60_L001_R1_001.fastq.gz
# ERR12383315       TF-2581-7_S7_L001_R1_001.fastq.gz
# ERR12383316       TF-2581-8_S8_L001_R1_001.fastq.gz
# ERR12383317     TF-2581-9e_S61_L001_R1_001.fastq.gz
#
#                              original_fastq_name_R2  \
# ERR12356072  TF-2581-10-e3_S67_L001_R2_001.fastq.gz
# ERR12383247      TF-2581-11_S9_L001_R2_001.fastq.gz
# ERR12383248     TF-2581-12_S10_L001_R2_001.fastq.gz
# ERR12383249     TF-2581-13_S11_L001_R2_001.fastq.gz
# ERR12383250  TF-2581-14-e2_S68_L001_R2_001.fastq.gz
# ...                                             ...
# ERR12383313     TF-2581-71_S59_L001_R2_001.fastq.gz
# ERR12383314     TF-2581-72_S60_L001_R2_001.fastq.gz
# ERR12383315       TF-2581-7_S7_L001_R2_001.fastq.gz
# ERR12383316       TF-2581-8_S8_L001_R2_001.fastq.gz
# ERR12383317     TF-2581-9e_S61_L001_R2_001.fastq.gz
#
#                                                          Notes
# ERR12356072                                                NaN
# ERR12383247                                                NaN
# ERR12383248                                                NaN
# ERR12383249                                                NaN
# ERR12383250                                                NaN
# ...                                                        ...
# ERR12383313  Had TF ID: TF2581-70, and Sample ID: 71 before...
# ERR12383314  Had TF ID: TF2581-71, and Sample ID: 72 before...
# ERR12383315                                                NaN
# ERR12383316                                                NaN
# ERR12383317                                                NaN
#
# [70 rows x 16 columns]

# %%
# create transpose
vst_t = norm_counts.T

pca = PCA(n_components=2)
pca_scores = pca.fit_transform(vst_t)

pca_df = metadata.copy()
pca_df['PC1'] = pca_scores[:,0]
pca_df['PC2'] = pca_scores[:,1]

# Explained variance
pc1_var = pca.explained_variance_ratio_[0] * 100
pc2_var = pca.explained_variance_ratio_[1] * 100

# Define your own color mapping
color_map = {'M': 'blue', 'F': 'red'}  

fig = px.scatter(
    pca_df,
    x='PC1',
    y='PC2',
    color='Sex',  
    color_discrete_map=color_map,          
    hover_name=pca_df.index,
    title=f"Salmon-Map: Male vs. Female PCA of VST-normalized counts"
)

fig.update_layout(
    xaxis_title=f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% var)",
    yaxis_title=f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% var)",
    width=1000
)

#fig.write_image("salmon_map_pca.svg")
fig.show()

# %% [markdown]
# Volcano Plot

# %%
results_full_annot = pd.read_csv("C:/Users/Sebas/OneDrive/Dokument/Master courses/MASTER THESIS/R project-Master Thesis/salmon_map_dominance_DE_sex_results_new_filtering_genotype_controlled_age_rank_fixed.csv", float_precision='legacy')
results_full_annot
# Out:
#          baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0      248.420188        0.640709  0.110526   5.796904  6.755020e-09
# 1       92.726112        0.650988  0.104454   6.232321  4.595741e-10
# 2      136.044931       -0.600974  0.070022  -8.582668  9.269779e-18
# 3        3.332468        2.699629  0.718636   3.756600  1.722376e-04
# 4      381.084979       -0.875080  0.046175 -18.951587  4.284679e-80
# ...           ...             ...       ...        ...           ...
# 17569   20.275098        0.319252  0.150056   2.127555  3.337403e-02
# 17570    1.364118        2.068769  0.590743   3.501981  4.618132e-04
# 17571    8.286716        1.984267  0.355927   5.574921  2.476423e-08
# 17572   19.121063        2.284212  0.326813   6.989347  2.761695e-12
# 17573    3.504696        1.065212  0.357173   2.982341  2.860533e-03
#
#                padj transcript_id gene_id     seqname chr_loc  ...  \
# 0      1.316673e-08         g2.t1      g2  utg000001l       A  ...
# 1      9.353175e-10         g3.t1      g3  utg000001l       A  ...
# 2      2.387530e-17         g4.t1      g4  utg000001l       A  ...
# 3      2.671748e-04         g5.t1      g5  utg000001l       A  ...
# 4      3.659726e-79         g6.t1      g6  utg000001l       A  ...
# ...             ...           ...     ...         ...     ...  ...
# 17569  4.238130e-02     g34843.t1  g34843  utg003648l       U  ...
# 17570  6.956768e-04     g34884.t1  g34884  utg003700l       U  ...
# 17571  4.718367e-08     g34922.t1  g34922  utg003714l       U  ...
# 17572  6.049015e-12     g35167.t1  g35167  utg003885l       U  ...
# 17573  4.036436e-03     g35420.t1  g35420  utg003980l       U  ...
#
#                                               eggNOG_OGs  \
# 0      2FBM0@1|root,2TCUK@2759|Eukaryota,398E5@33154|...
# 1      KOG2101@1|root,KOG2101@2759|Eukaryota,396Y9@33...
# 2      COG0181@1|root,KOG2892@2759|Eukaryota,38D6W@33...
# 3      KOG2761@1|root,KOG2761@2759|Eukaryota,38F7R@33...
# 4                      2E6V3@1|root,2SDHR@2759|Eukaryota
# ...                                                  ...
# 17569                                                NaN
# 17570  2D3G7@1|root,2SRFN@2759|Eukaryota,3AMW9@33154|...
# 17571                                                NaN
# 17572                                                NaN
# 17573  KOG1075@1|root,KOG1075@2759|Eukaryota,39TZY@33...
#
#                              species_tree_birth_node gene_tree_birth_node  \
# 0      C_maculatus_filtered_proteinfasta_TE_filtered                   n3
# 1      C_maculatus_filtered_proteinfasta_TE_filtered                   n9
# 2      C_maculatus_filtered_proteinfasta_TE_filtered                  n13
# 3      C_maculatus_filtered_proteinfasta_TE_filtered                   n8
# 4                                                 N8                  NaN
# ...                                              ...                  ...
# 17569                                            NaN                  NaN
# 17570  C_maculatus_filtered_proteinfasta_TE_filtered                  n17
# 17571  C_maculatus_filtered_proteinfasta_TE_filtered                  n43
# 17572                                            NaN                  NaN
# 17573  C_maculatus_filtered_proteinfasta_TE_filtered                  n31
#
#           birth_type age_rank  age_category node_depth_from_root  \
# 0        duplication      9.0        recent             0.758700
# 1        duplication      9.0        recent             0.758700
# 2        duplication      9.0        recent             0.758700
# 3        duplication      9.0        recent             0.758700
# 4      mrca_inferred      6.0  intermediate             0.629385
# ...              ...      ...           ...                  ...
# 17569            NaN      NaN           NaN                  NaN
# 17570    duplication      9.0        recent             0.758700
# 17571    duplication      9.0        recent             0.758700
# 17572            NaN      NaN           NaN                  NaN
# 17573    duplication      9.0        recent             0.758700
#
#       branch_length n_copies_in_og n_species_in_og
# 0          0.061748            2.0             8.0
# 1          0.061748            2.0            14.0
# 2          0.061748            2.0            14.0
# 3          0.061748            2.0            12.0
# 4          0.171468            1.0             4.0
# ...             ...            ...             ...
# 17569           NaN            NaN             NaN
# 17570      0.061748           23.0             4.0
# 17571      0.061748           22.0             6.0
# 17572           NaN            NaN             NaN
# 17573      0.061748           13.0             6.0
#
# [17574 rows x 34 columns]

# %%
# Replace the zeros in padj with 1e-308 avoid log10 issues
results_full_annot["padj_safe"] = results_full_annot["padj"].replace(0, 1e-308).fillna(1)

# Add the negative log 10 padj for plotting
results_full_annot["neglog10_padj"] = -np.log10(results_full_annot["padj_safe"])


# Add significance to differentially expressed genes 
results_full_annot["significant"] = (
    (results_full_annot["padj"] < 0.05) &
    (results_full_annot["log2FoldChange"].abs() > 1)
)

# Add a label to the significant genes
results_full_annot["label"] = results_full_annot["gene_id"].where(results_full_annot["significant"], "")

results_full_annot
# Out:
#          baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0      248.420188        0.640709  0.110526   5.796904  6.755020e-09
# 1       92.726112        0.650988  0.104454   6.232321  4.595741e-10
# 2      136.044931       -0.600974  0.070022  -8.582668  9.269779e-18
# 3        3.332468        2.699629  0.718636   3.756600  1.722376e-04
# 4      381.084979       -0.875080  0.046175 -18.951587  4.284679e-80
# ...           ...             ...       ...        ...           ...
# 17569   20.275098        0.319252  0.150056   2.127555  3.337403e-02
# 17570    1.364118        2.068769  0.590743   3.501981  4.618132e-04
# 17571    8.286716        1.984267  0.355927   5.574921  2.476423e-08
# 17572   19.121063        2.284212  0.326813   6.989347  2.761695e-12
# 17573    3.504696        1.065212  0.357173   2.982341  2.860533e-03
#
#                padj transcript_id gene_id     seqname chr_loc  ...  age_rank  \
# 0      1.316673e-08         g2.t1      g2  utg000001l       A  ...       9.0
# 1      9.353175e-10         g3.t1      g3  utg000001l       A  ...       9.0
# 2      2.387530e-17         g4.t1      g4  utg000001l       A  ...       9.0
# 3      2.671748e-04         g5.t1      g5  utg000001l       A  ...       9.0
# 4      3.659726e-79         g6.t1      g6  utg000001l       A  ...       6.0
# ...             ...           ...     ...         ...     ...  ...       ...
# 17569  4.238130e-02     g34843.t1  g34843  utg003648l       U  ...       NaN
# 17570  6.956768e-04     g34884.t1  g34884  utg003700l       U  ...       9.0
# 17571  4.718367e-08     g34922.t1  g34922  utg003714l       U  ...       9.0
# 17572  6.049015e-12     g35167.t1  g35167  utg003885l       U  ...       NaN
# 17573  4.036436e-03     g35420.t1  g35420  utg003980l       U  ...       9.0
#
#        age_category node_depth_from_root branch_length n_copies_in_og  \
# 0            recent             0.758700      0.061748            2.0
# 1            recent             0.758700      0.061748            2.0
# 2            recent             0.758700      0.061748            2.0
# 3            recent             0.758700      0.061748            2.0
# 4      intermediate             0.629385      0.171468            1.0
# ...             ...                  ...           ...            ...
# 17569           NaN                  NaN           NaN            NaN
# 17570        recent             0.758700      0.061748           23.0
# 17571        recent             0.758700      0.061748           22.0
# 17572           NaN                  NaN           NaN            NaN
# 17573        recent             0.758700      0.061748           13.0
#
#       n_species_in_og     padj_safe neglog10_padj significant   label
# 0                 8.0  1.316673e-08      7.880522       False
# 1                14.0  9.353175e-10      9.029041       False
# 2                14.0  2.387530e-17     16.622051       False
# 3                12.0  2.671748e-04      3.573204        True      g5
# 4                 4.0  3.659726e-79     78.436551       False
# ...               ...           ...           ...         ...     ...
# 17569             NaN  4.238130e-02      1.372826       False
# 17570             4.0  6.956768e-04      3.157592        True  g34884
# 17571             6.0  4.718367e-08      7.326208        True  g34922
# 17572             NaN  6.049015e-12     11.218315        True  g35167
# 17573             6.0  4.036436e-03      2.394002        True  g35420
#
# [17574 rows x 38 columns]

# %%
fig = px.scatter(
    results_full_annot,
    x="log2FoldChange",
    y="neglog10_padj",
    hover_name="transcript_id",
    hover_data=["padj", "HOG", "PFAMs"],  # Use the columns that already exist
    color="significant",
    color_discrete_map={True: "red", False: "blue"},
    title="Salmon-Map: Volcano Plot (Male vs. Female Transcript Expression)"
)

fig.update_traces(textposition='top center', textfont_size=8)

fig.update_layout(
    xaxis_title="log2 Fold Change (male vs female)",
    yaxis_title="-log10(padj (FDR))",
    width = 1000
)

# Horizontal FDR=0.05 cutoff
padj_cut = -np.log10(0.05)

fig.add_hline(
    y=padj_cut,
    line_dash="dash",
    line_color="grey",
    annotation_text="padj = 0.05",
    annotation_position="bottom right"
)

# Vertical log2FC cutoffs
fig.add_vline(
    x=-1,
    line_dash="dash",
    line_color="grey",
    annotation_text="log2FC = -1",
    annotation_position="top left"
)
fig.add_vline(
    x=1,
    line_dash="dash",
    line_color="grey",
    annotation_text="log2FC = 1",
    annotation_position="top right"
)
#fig.write_image("salmon_map_volcano.svg")
fig.show()


#DE genes
sig_counts = results_full_annot["significant"].sum()
higher_in_m = ((results_full_annot["significant"]) & 
               (results_full_annot["log2FoldChange"] > 0)).sum()
higher_in_f = ((results_full_annot["significant"]) & 
               (results_full_annot["log2FoldChange"] < 0)).sum()

print(f"Total significant transcripts: {sig_counts}")
print(f"Higher in males: {higher_in_m}")
print(f"Higher in females: {higher_in_f}")
# Out:
# Total significant transcripts: 7270
# Higher in males: 5070
# Higher in females: 2200

# %% [markdown]
# Significant Transcripts

# %%
sig_transcripts = results_full_annot[results_full_annot["significant"]]

sig_transcripts
# Out:
#          baseMean  log2FoldChange     lfcSE       stat         pvalue  \
# 3        3.332468        2.699629  0.718636   3.756600   1.722376e-04
# 5       70.718212       -1.039030  0.089153 -11.654489   2.176813e-31
# 6      475.721002        1.120124  0.059428  18.848397   3.028815e-79
# 7       97.175715        1.341896  0.124766  10.755269   5.597042e-27
# 11     237.620281       -4.015786  0.186764 -21.501956  1.492615e-102
# ...           ...             ...       ...        ...            ...
# 17566    1.283803        1.996209  0.614968   3.246035   1.170246e-03
# 17570    1.364118        2.068769  0.590743   3.501981   4.618132e-04
# 17571    8.286716        1.984267  0.355927   5.574921   2.476423e-08
# 17572   19.121063        2.284212  0.326813   6.989347   2.761695e-12
# 17573    3.504696        1.065212  0.357173   2.982341   2.860533e-03
#
#                 padj transcript_id gene_id     seqname chr_loc  ...  age_rank  \
# 3       2.671748e-04         g5.t1      g5  utg000001l       A  ...       9.0
# 5       7.787918e-31         g7.t1      g7  utg000001l       A  ...       1.0
# 6       2.541218e-78         g8.t1      g8  utg000001l       A  ...       1.0
# 7       1.811622e-26         g9.t1      g9  utg000001l       A  ...       8.0
# 11     1.902623e-101        g13.t1     g13  utg000001l       A  ...       8.0
# ...              ...           ...     ...         ...     ...  ...       ...
# 17566   1.707534e-03     g34618.t1  g34618  utg003533l       U  ...       NaN
# 17570   6.956768e-04     g34884.t1  g34884  utg003700l       U  ...       9.0
# 17571   4.718367e-08     g34922.t1  g34922  utg003714l       U  ...       9.0
# 17572   6.049015e-12     g35167.t1  g35167  utg003885l       U  ...       NaN
# 17573   4.036436e-03     g35420.t1  g35420  utg003980l       U  ...       9.0
#
#        age_category node_depth_from_root branch_length n_copies_in_og  \
# 3            recent             0.758700      0.061748            2.0
# 5           ancient             0.000000      0.000000            1.0
# 6           ancient             0.000000      0.000000            1.0
# 7            recent             0.696952      0.035914            2.0
# 11           recent             0.696952      0.035914            1.0
# ...             ...                  ...           ...            ...
# 17566           NaN                  NaN           NaN            NaN
# 17570        recent             0.758700      0.061748           23.0
# 17571        recent             0.758700      0.061748           22.0
# 17572           NaN                  NaN           NaN            NaN
# 17573        recent             0.758700      0.061748           13.0
#
#       n_species_in_og      padj_safe neglog10_padj significant   label
# 3                12.0   2.671748e-04      3.573204        True      g5
# 5                12.0   7.787918e-31     30.108579        True      g7
# 6                12.0   2.541218e-78     77.594958        True      g8
# 7                14.0   1.811622e-26     25.741932        True      g9
# 11               14.0  1.902623e-101    100.720647        True     g13
# ...               ...            ...           ...         ...     ...
# 17566             NaN   1.707534e-03      2.767631        True  g34618
# 17570             4.0   6.956768e-04      3.157592        True  g34884
# 17571             6.0   4.718367e-08      7.326208        True  g34922
# 17572             NaN   6.049015e-12     11.218315        True  g35167
# 17573             6.0   4.036436e-03      2.394002        True  g35420
#
# [7270 rows x 38 columns]
