# %% [markdown]
# For the unfiltered, consistent annotations, using the whole genome decoys.

# %% [markdown]
# Load packages

# %%
import numpy as np
import pandas as pd
import plotly.express as px

from sklearn.decomposition import PCA

# %% [markdown]
# PCA

# %% [markdown]
# Load the datasets created in R

# %%
norm_counts = pd.read_csv("C:/Users/Sebas/OneDrive/Dokument/Master courses/MASTER THESIS/R project-Master Thesis/salmon_mapping_normalized_counts_transcript_consistent.csv", index_col=0)
norm_counts
# Out:
#            ERR12356072  ERR12383247  ERR12383248  ERR12383249  ERR12383250  \
# g2.t1         8.269478     8.411241     8.526792     9.196206     8.761699
# g3.t1         7.676883     7.586117     7.976149     7.751006     8.253937
# g4.t1         7.998226     8.004242     7.967495     7.601819     7.626103
# g6.t1         8.857844     9.208876     8.695234     8.379017     8.658400
# g7.t1         7.427148     7.617265     7.644402     7.159220     7.077886
# ...                ...          ...          ...          ...          ...
# g34647.t1     6.100853     6.443883     6.100853     6.100853     6.100853
# g34695.t1     6.582874     6.635310     6.431194     6.555552     6.571327
# g34843.t1     6.638034     6.901771     6.986471     7.007302     6.723739
# g34922.t1     6.469439     6.453611     6.443901     6.500045     6.461610
# g35167.t1     6.491391     6.531157     6.896498     6.941661     6.613138
#
#            ERR12383251  ERR12383252  ERR12383253  ERR12383254  ERR12383255  \
# g2.t1         9.388722     8.196752     8.402496     8.457306     9.013395
# g3.t1         8.062046     7.468303     7.967180     7.723920     7.907020
# g4.t1         7.599612     7.947343     7.853719     8.067351     7.593541
# g6.t1         8.541016     9.167440     8.904972     9.083919     8.702906
# g7.t1         7.027853     7.800402     7.805647     7.730926     6.865799
# ...                ...          ...          ...          ...          ...
# g34647.t1     6.100853     6.513204     6.876698     6.100853     6.100853
# g34695.t1     6.502017     6.645298     6.627552     6.631873     6.428449
# g34843.t1     7.168782     6.796147     6.653871     6.765013     7.054272
# g34922.t1     6.782296     6.496910     6.308682     6.489032     6.100853
# g35167.t1     6.961166     6.660516     6.718332     7.090118     6.428138
#
#            ...  ERR12383308  ERR12383309  ERR12383310  ERR12383311  \
# g2.t1      ...     8.747931     8.489685     8.687306     8.135020
# g3.t1      ...     7.379459     7.622685     7.291832     6.883376
# g4.t1      ...     7.812783     7.832789     7.833963     7.973990
# g6.t1      ...     8.541724     8.552082     8.773682     9.004860
# g7.t1      ...     7.656500     7.161806     7.057765     7.713017
# ...        ...          ...          ...          ...          ...
# g34647.t1  ...     7.704144     7.717864     7.561406     7.132786
# g34695.t1  ...     7.057874     6.738237     6.622011     6.618945
# g34843.t1  ...     6.522571     6.242138     6.414917     6.834661
# g34922.t1  ...     7.316538     6.671459     6.519037     6.516150
# g35167.t1  ...     7.927682     6.658432     6.590961     6.647146
#
#            ERR12383312  ERR12383313  ERR12383314  ERR12383315  ERR12383316  \
# g2.t1         8.241102     8.639667     8.212894     8.497760     8.562085
# g3.t1         7.112085     7.183057     7.232616     8.108190     8.238908
# g4.t1         7.992453     7.883665     7.899324     7.590031     7.642158
# g6.t1         9.207049     9.228235     9.177616     8.598613     8.362338
# g7.t1         7.474460     7.495654     7.633983     7.484323     7.440095
# ...                ...          ...          ...          ...          ...
# g34647.t1     7.520370     7.418286     7.469274     6.100853     6.100853
# g34695.t1     6.574105     6.690440     6.692981     6.663610     6.398528
# g34843.t1     6.357598     6.363800     6.652935     7.198652     6.898608
# g34922.t1     6.334359     6.467500     6.481889     6.898065     6.100853
# g35167.t1     6.587963     6.459344     6.366707     7.948822     7.041883
#
#            ERR12383317
# g2.t1         9.208239
# g3.t1         7.950329
# g4.t1         7.197193
# g6.t1         8.280426
# g7.t1         7.265077
# ...                ...
# g34647.t1     6.446611
# g34695.t1     6.398980
# g34843.t1     6.927488
# g34922.t1     6.443156
# g35167.t1     7.323870
#
# [14164 rows x 70 columns]

# %%
#Metadata
metadata = pd.read_csv("C:/Users/Sebas/OneDrive/Dokument/Master courses/MASTER THESIS/R project-Master Thesis/dominance_meta_corrected_outlier_corrected.csv")

#make sure order matches norm_counts
metadata = metadata.set_index('Run')
metadata = metadata.reindex(norm_counts.columns)
# Now Run is the index, and metadata is aligned with counts
print("Metadata index (samples):", metadata.index[:5].tolist())
print("Counts columns:", norm_counts.columns[:5].tolist())
print("Match?", all(metadata.index == norm_counts.columns))
metadata
# Out:
# Metadata index (samples): ['ERR12356072', 'ERR12383247', 'ERR12383248', 'ERR12383249', 'ERR12383250']
# Counts columns: ['ERR12356072', 'ERR12383247', 'ERR12383248', 'ERR12383249', 'ERR12383250']
# Match? True
#                    Bases  BioProject       BioSample   Experiment  \
# ERR12356072  21027960416  PRJEB70958  SAMEA114860228  ERX11733017
# ERR12383247  14794943760  PRJEB70958  SAMEA114860213  ERX11759665
# ERR12383248  15610248328  PRJEB70958  SAMEA114860214  ERX11759666
# ERR12383249   9412089720  PRJEB70958  SAMEA114860215  ERX11759667
# ERR12383250   9959631122  PRJEB70958  SAMEA114860216  ERX11759668
# ...                  ...         ...             ...          ...
# ERR12383313  27406244206  PRJEB70958  SAMEA114860279  ERX11759731
# ERR12383314  13458064958  PRJEB70958  SAMEA114860280  ERX11759732
# ERR12383315  11890141660  PRJEB70958  SAMEA114860281  ERX11759733
# ERR12383316  13692674262  PRJEB70958  SAMEA114860282  ERX11759734
# ERR12383317  14658478416  PRJEB70958  SAMEA114860283  ERX11759735
#
#                                          sample_name         TF ID Sample ID  \
# ERR12356072  Sample 1 males genotype BA heterozygote  TF2581-10-e3     10e 3
# ERR12383247  Sample 1 females genotype AA homozygote     TF2581-11        11
# ERR12383248  Sample 2 females genotype AA homozygote     TF2581-12        12
# ERR12383249  Sample 3 females genotype AA homozygote     TF2581-13        13
# ERR12383250    Sample 1 males genotype AA homozygote  TF2581-14-e2     14e 2
# ...                                              ...           ...       ...
# ERR12383313  Sample 1 females genotype FF homozygote     TF2581-71        71
# ERR12383314  Sample 2 females genotype FF homozygote     TF2581-72        72
# ERR12383315  Sample 3 females genotype FF homozygote      TF2581-7         7
# ERR12383316    Sample 1 males genotype FF homozygote      TF2581-8         8
# ERR12383317    Sample 2 males genotype FF homozygote     TF2581-9e        9e
#
#                              Cross  Family Sex  \
# ERR12356072  13:20 (M) + 42:13 (F)  2,3,4,   F
# ERR12383247  13:20 (M) + 42:13 (F)  2,3,4,   F
# ERR12383248  13:20 (M) + 42:13 (F)  2,3,4,   F
# ERR12383249  42:13 (M) + 13:20 (F)   1,4,8   M
# ERR12383250  42:13 (M) + 13:20 (F)   1,4,8   M
# ...                            ...     ...  ..
# ERR12383313            4:18 + 4:18   2,6,9   F
# ERR12383314            4:18 + 4:18   2,6,9   F
# ERR12383315  13:20 (M) + 42:13 (F)  2,3,4,   M
# ERR12383316  13:20 (M) + 42:13 (F)  2,3,4,   M
# ERR12383317  13:20 (M) + 42:13 (F)  2,3,4,   M
#
#                              original_fastq_name_R1  \
# ERR12356072  TF-2581-10-e3_S67_L001_R1_001.fastq.gz
# ERR12383247      TF-2581-11_S9_L001_R1_001.fastq.gz
# ERR12383248     TF-2581-12_S10_L001_R1_001.fastq.gz
# ERR12383249     TF-2581-13_S11_L001_R1_001.fastq.gz
# ERR12383250  TF-2581-14-e2_S68_L001_R1_001.fastq.gz
# ...                                             ...
# ERR12383313     TF-2581-71_S59_L001_R1_001.fastq.gz
# ERR12383314     TF-2581-72_S60_L001_R1_001.fastq.gz
# ERR12383315       TF-2581-7_S7_L001_R1_001.fastq.gz
# ERR12383316       TF-2581-8_S8_L001_R1_001.fastq.gz
# ERR12383317     TF-2581-9e_S61_L001_R1_001.fastq.gz
#
#                              original_fastq_name_R2  \
# ERR12356072  TF-2581-10-e3_S67_L001_R2_001.fastq.gz
# ERR12383247      TF-2581-11_S9_L001_R2_001.fastq.gz
# ERR12383248     TF-2581-12_S10_L001_R2_001.fastq.gz
# ERR12383249     TF-2581-13_S11_L001_R2_001.fastq.gz
# ERR12383250  TF-2581-14-e2_S68_L001_R2_001.fastq.gz
# ...                                             ...
# ERR12383313     TF-2581-71_S59_L001_R2_001.fastq.gz
# ERR12383314     TF-2581-72_S60_L001_R2_001.fastq.gz
# ERR12383315       TF-2581-7_S7_L001_R2_001.fastq.gz
# ERR12383316       TF-2581-8_S8_L001_R2_001.fastq.gz
# ERR12383317     TF-2581-9e_S61_L001_R2_001.fastq.gz
#
#                                                Notes
# ERR12356072                                      NaN
# ERR12383247                                      NaN
# ERR12383248                                      NaN
# ERR12383249                                      NaN
# ERR12383250                                      NaN
# ...                                              ...
# ERR12383313  Had TF ID: TF2581-70, and Sample ID: 71
# ERR12383314  Had TF ID: TF2581-71, and Sample ID: 72
# ERR12383315                                      NaN
# ERR12383316                                      NaN
# ERR12383317                                      NaN
#
# [70 rows x 13 columns]

# %%
# create transpose
vst_t = norm_counts.T

pca = PCA(n_components=2)
pca_scores = pca.fit_transform(vst_t)

pca_df = metadata.copy()
pca_df['PC1'] = pca_scores[:,0]
pca_df['PC2'] = pca_scores[:,1]

# Explained variance
pc1_var = pca.explained_variance_ratio_[0] * 100
pc2_var = pca.explained_variance_ratio_[1] * 100

# Define your own color mapping
color_map = {'M': 'blue', 'F': 'red'}  

fig = px.scatter(
    pca_df,
    x='PC1',
    y='PC2',
    color='Sex',  
    color_discrete_map=color_map,          
    hover_name=pca_df.index,
    title=f"Salmon-Map: Male vs. Female PCA of VST-normalized counts"
)

fig.update_layout(
    xaxis_title=f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% var)",
    yaxis_title=f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% var)",
)
fig.show()

# %% [markdown]
# Volcano Plot

# %%
results_full_annot = pd.read_csv("C:/Users/Sebas/OneDrive/Dokument/Master courses/MASTER THESIS/R project-Master Thesis/salmon_map_dominance_DE_sex_results.csv", float_precision='legacy')
results_full_annot
# Out:
#          baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0      248.420188        0.692248  0.131010   5.283945  1.264310e-07
# 1       92.726112        0.655816  0.169767   3.863035  1.119872e-04
# 2      136.044931       -0.620457  0.178648  -3.473064  5.145527e-04
# 3      381.084979       -0.916813  0.069608 -13.171077  1.287480e-39
# 4       70.718212       -1.042894  0.092940 -11.221090  3.212849e-29
# ...           ...             ...       ...        ...           ...
# 14159   10.439363        0.155829  1.106835   0.140788  8.880376e-01
# 14160   10.044300        0.631293  0.230505   2.738741  6.167502e-03
# 14161   20.275098        0.380299  0.210397   1.807533  7.067915e-02
# 14162    8.286716        2.238606  0.365799   6.119773  9.370857e-10
# 14163   19.121063        2.377056  0.338256   7.027380  2.104477e-12
#
#                padj transcript_id gene_id     seqname     start  ...  \
# 0      2.436236e-07         g2.t1      g2  utg000001l  220384.0  ...
# 1      1.816552e-04         g3.t1      g3  utg000001l  227675.0  ...
# 2      7.936587e-04         g4.t1      g4  utg000001l  245866.0  ...
# 3      7.390355e-39         g6.t1      g6  utg000001l  263441.0  ...
# 4      1.373292e-28         g7.t1      g7  utg000001l  371755.0  ...
# ...             ...           ...     ...         ...       ...  ...
# 14159  8.997925e-01     g34647.t1  g34647  utg003542l   22333.0  ...
# 14160  8.691213e-03     g34695.t1  g34695  utg003603l       1.0  ...
# 14161  8.783567e-02     g34843.t1  g34843  utg003648l    5656.0  ...
# 14162  2.009399e-09     g34922.t1  g34922  utg003714l       1.0  ...
# 14163  5.052814e-12     g35167.t1  g35167  utg003885l       1.0  ...
#
#                  HOG         OG Gene.Tree.Parent.Clade  \
# 0      N0.HOG0012111  OG0011460                     n0
# 1      N0.HOG0004052  OG0003481                     n0
# 2      N0.HOG0004826  OG0004221                     n0
# 3      N0.HOG0015574  OG0014921                     n0
# 4      N0.HOG0010167  OG0009526                     n0
# ...              ...        ...                    ...
# 14159  N0.HOG0001989  OG0001593                     n0
# 14160            NaN        NaN                    NaN
# 14161  N0.HOG0012740  OG0012089                     n0
# 14162  N0.HOG0000406  OG0000247                     n0
# 14163            NaN        NaN                    NaN
#
#                                 PFAMs  \
# 0                                COX8
# 1          PX,Pkinase,Pkinase_Tyr,WH2
# 2      Porphobil_deam,Porphobil_deamC
# 3                                THAP
# 4                            CH,LRR_8
# ...                               ...
# 14159           LRR_5,LRR_8,TIR,TIR_2
# 14160                  Staufen_C,dsrm
# 14161                             NaN
# 14162                             NaN
# 14163                             NaN
#
#                                                      GOs        EC  \
# 0                                                      -         -
# 1      GO:0003674,GO:0005488,GO:0005515,GO:0005543,GO...  3.1.26.5
# 2      GO:0001101,GO:0001666,GO:0003674,GO:0003824,GO...  2.5.1.61
# 3                                                      -         -
# 4      GO:0002682,GO:0002683,GO:0002685,GO:0002686,GO...         -
# ...                                                  ...       ...
# 14159                                                  -         -
# 14160  GO:0000003,GO:0000578,GO:0000932,GO:0001709,GO...         -
# 14161                                                NaN       NaN
# 14162                                                NaN       NaN
# 14163                                                NaN       NaN
#
#                    KEGG_ko                                       KEGG_Pathway  \
# 0                ko:K02273  ko00190,ko01100,ko04260,ko04714,ko04932,ko0501...
# 1      ko:K14529,ko:K17543                                   ko03013,map03013
# 2                ko:K01749  ko00860,ko01100,ko01110,ko01120,map00860,map01...
# 3                        -                                                  -
# 4                        -                                                  -
# ...                    ...                                                ...
# 14159                    -                                                  -
# 14160            ko:K17597                                                  -
# 14161                  NaN                                                NaN
# 14162                  NaN                                                NaN
# 14163                  NaN                                                NaN
#
#       COG_category                                         eggNOG_OGs
# 0                I  2FBM0@1|root,2TCUK@2759|Eukaryota,398E5@33154|...
# 1              DUZ  KOG2101@1|root,KOG2101@2759|Eukaryota,396Y9@33...
# 2                H  COG0181@1|root,KOG2892@2759|Eukaryota,38D6W@33...
# 3                B                  2E6V3@1|root,2SDHR@2759|Eukaryota
# 4                Z  COG4886@1|root,KOG0532@2759|Eukaryota,38HCP@33...
# ...            ...                                                ...
# 14159            T  COG4886@1|root,KOG4641@2759|Eukaryota,39T87@33...
# 14160           KU  KOG3732@1|root,KOG3732@2759|Eukaryota,38HNW@33...
# 14161          NaN                                                NaN
# 14162          NaN                                                NaN
# 14163          NaN                                                NaN
#
# [14164 rows x 24 columns]

# %%
# Replace the zeros in padj with 1e-308 avoid log10 issues
results_full_annot["padj_safe"] = results_full_annot["padj"].replace(0, 1e-308).fillna(1)

# Add the negative log 10 padj for plotting
results_full_annot["neglog10_padj"] = -np.log10(results_full_annot["padj_safe"])


# Add significance to differentially expressed genes 
results_full_annot["significant"] = (
    (results_full_annot["padj"] < 0.05) &
    (results_full_annot["log2FoldChange"].abs() > 1)
)

# Add a label to the significant genes
results_full_annot["label"] = results_full_annot["gene_id"].where(results_full_annot["significant"], "")

results_full_annot
# Out:
#          baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0      248.420188        0.692248  0.131010   5.283945  1.264310e-07
# 1       92.726112        0.655816  0.169767   3.863035  1.119872e-04
# 2      136.044931       -0.620457  0.178648  -3.473064  5.145527e-04
# 3      381.084979       -0.916813  0.069608 -13.171077  1.287480e-39
# 4       70.718212       -1.042894  0.092940 -11.221090  3.212849e-29
# ...           ...             ...       ...        ...           ...
# 14159   10.439363        0.155829  1.106835   0.140788  8.880376e-01
# 14160   10.044300        0.631293  0.230505   2.738741  6.167502e-03
# 14161   20.275098        0.380299  0.210397   1.807533  7.067915e-02
# 14162    8.286716        2.238606  0.365799   6.119773  9.370857e-10
# 14163   19.121063        2.377056  0.338256   7.027380  2.104477e-12
#
#                padj transcript_id gene_id     seqname     start  ...  \
# 0      2.436236e-07         g2.t1      g2  utg000001l  220384.0  ...
# 1      1.816552e-04         g3.t1      g3  utg000001l  227675.0  ...
# 2      7.936587e-04         g4.t1      g4  utg000001l  245866.0  ...
# 3      7.390355e-39         g6.t1      g6  utg000001l  263441.0  ...
# 4      1.373292e-28         g7.t1      g7  utg000001l  371755.0  ...
# ...             ...           ...     ...         ...       ...  ...
# 14159  8.997925e-01     g34647.t1  g34647  utg003542l   22333.0  ...
# 14160  8.691213e-03     g34695.t1  g34695  utg003603l       1.0  ...
# 14161  8.783567e-02     g34843.t1  g34843  utg003648l    5656.0  ...
# 14162  2.009399e-09     g34922.t1  g34922  utg003714l       1.0  ...
# 14163  5.052814e-12     g35167.t1  g35167  utg003885l       1.0  ...
#
#                                                      GOs        EC  \
# 0                                                      -         -
# 1      GO:0003674,GO:0005488,GO:0005515,GO:0005543,GO...  3.1.26.5
# 2      GO:0001101,GO:0001666,GO:0003674,GO:0003824,GO...  2.5.1.61
# 3                                                      -         -
# 4      GO:0002682,GO:0002683,GO:0002685,GO:0002686,GO...         -
# ...                                                  ...       ...
# 14159                                                  -         -
# 14160  GO:0000003,GO:0000578,GO:0000932,GO:0001709,GO...         -
# 14161                                                NaN       NaN
# 14162                                                NaN       NaN
# 14163                                                NaN       NaN
#
#                    KEGG_ko                                       KEGG_Pathway  \
# 0                ko:K02273  ko00190,ko01100,ko04260,ko04714,ko04932,ko0501...
# 1      ko:K14529,ko:K17543                                   ko03013,map03013
# 2                ko:K01749  ko00860,ko01100,ko01110,ko01120,map00860,map01...
# 3                        -                                                  -
# 4                        -                                                  -
# ...                    ...                                                ...
# 14159                    -                                                  -
# 14160            ko:K17597                                                  -
# 14161                  NaN                                                NaN
# 14162                  NaN                                                NaN
# 14163                  NaN                                                NaN
#
#       COG_category                                         eggNOG_OGs  \
# 0                I  2FBM0@1|root,2TCUK@2759|Eukaryota,398E5@33154|...
# 1              DUZ  KOG2101@1|root,KOG2101@2759|Eukaryota,396Y9@33...
# 2                H  COG0181@1|root,KOG2892@2759|Eukaryota,38D6W@33...
# 3                B                  2E6V3@1|root,2SDHR@2759|Eukaryota
# 4                Z  COG4886@1|root,KOG0532@2759|Eukaryota,38HCP@33...
# ...            ...                                                ...
# 14159            T  COG4886@1|root,KOG4641@2759|Eukaryota,39T87@33...
# 14160           KU  KOG3732@1|root,KOG3732@2759|Eukaryota,38HNW@33...
# 14161          NaN                                                NaN
# 14162          NaN                                                NaN
# 14163          NaN                                                NaN
#
#           padj_safe neglog10_padj significant   label
# 0      2.436236e-07      6.613281       False
# 1      1.816552e-04      3.740752       False
# 2      7.936587e-04      3.100366       False
# 3      7.390355e-39     38.131335       False
# 4      1.373292e-28     27.862237        True      g7
# ...             ...           ...         ...     ...
# 14159  8.997925e-01      0.045858       False
# 14160  8.691213e-03      2.060920       False
# 14161  8.783567e-02      1.056329       False
# 14162  2.009399e-09      8.696934        True  g34922
# 14163  5.052814e-12     11.296467        True  g35167
#
# [14164 rows x 28 columns]

# %%
fig = px.scatter(
    results_full_annot,
    x="log2FoldChange",
    y="neglog10_padj",
    hover_name="transcript_id",
    hover_data=["padj", "HOG", "PFAMs"],  # Use the columns that already exist
    color="significant",
    color_discrete_map={True: "red", False: "blue"},
    title="Salmon-Map: Volcano Plot (Male vs. Female Transcript Expression)"
)

fig.update_traces(textposition='top center', textfont_size=8)

fig.update_layout(
    xaxis_title="log2 Fold Change (male vs female)",
    yaxis_title="-log10(padj (FDR))",
)

# Horizontal FDR=0.05 cutoff
padj_cut = -np.log10(0.05)

fig.add_hline(
    y=padj_cut,
    line_dash="dash",
    line_color="grey",
    annotation_text="padj = 0.05",
    annotation_position="bottom right"
)

# Vertical log2FC cutoffs
fig.add_vline(
    x=-1,
    line_dash="dash",
    line_color="grey",
    annotation_text="log2FC = -1",
    annotation_position="top left"
)
fig.add_vline(
    x=1,
    line_dash="dash",
    line_color="grey",
    annotation_text="log2FC = 1",
    annotation_position="top right"
)

fig.show()


#DE genes
sig_counts = results_full_annot["significant"].sum()
higher_in_m = ((results_full_annot["significant"]) & 
               (results_full_annot["log2FoldChange"] > 0)).sum()
higher_in_f = ((results_full_annot["significant"]) & 
               (results_full_annot["log2FoldChange"] < 0)).sum()

print(f"Total significant transcripts: {sig_counts}")
print(f"Higher in males: {higher_in_m}")
print(f"Higher in females: {higher_in_f}")
# Out:
# Total significant transcripts: 5061
# Higher in males: 3189
# Higher in females: 1872

# %% [markdown]
# Significant Transcripts

# %%
sig_transcripts = results_full_annot[results_full_annot["significant"]]

sig_transcripts
# Out:
#          baseMean  log2FoldChange     lfcSE       stat         pvalue  \
# 4       70.718212       -1.042894  0.092940 -11.221090   3.212849e-29
# 5      475.721002        1.108108  0.072356  15.314587   6.109909e-53
# 6       97.175715        1.440532  0.178901   8.052107   8.138076e-16
# 10     237.620281       -3.903644  0.196957 -19.819734   2.011674e-87
# 12     961.410546       -4.357921  0.168953 -25.793707  1.043262e-146
# ...           ...             ...       ...        ...            ...
# 14149    8.778626        1.536700  0.325180   4.725686   2.293403e-06
# 14151   15.731924       -1.548799  0.357538  -4.331846   1.478646e-05
# 14154   33.909303        1.467955  0.315215   4.656992   3.208635e-06
# 14162    8.286716        2.238606  0.365799   6.119773   9.370857e-10
# 14163   19.121063        2.377056  0.338256   7.027380   2.104477e-12
#
#                 padj transcript_id gene_id     seqname     start  ...  \
# 4       1.373292e-28         g7.t1      g7  utg000001l  371755.0  ...
# 5       4.975412e-52         g8.t1      g8  utg000001l  510966.0  ...
# 6       2.241651e-15         g9.t1      g9  utg000001l  531498.0  ...
# 10      3.512616e-86        g13.t1     g13  utg000001l  666271.0  ...
# 12     6.566061e-145        g15.t1     g15  utg000001l  789435.0  ...
# ...              ...           ...     ...         ...       ...  ...
# 14149   4.128766e-06     g33982.t1  g33982  utg003197l       1.0  ...
# 14151   2.542697e-05     g34016.t1  g34016  utg003227l       1.0  ...
# 14154   5.724767e-06     g34172.t1  g34172  utg003311l       1.0  ...
# 14162   2.009399e-09     g34922.t1  g34922  utg003714l       1.0  ...
# 14163   5.052814e-12     g35167.t1  g35167  utg003885l       1.0  ...
#
#                                                      GOs        EC  \
# 4      GO:0002682,GO:0002683,GO:0002685,GO:0002686,GO...         -
# 5      GO:0005575,GO:0005623,GO:0005886,GO:0005887,GO...         -
# 6      GO:0003674,GO:0005488,GO:0005509,GO:0043167,GO...         -
# 10     GO:0000003,GO:0000022,GO:0000070,GO:0000226,GO...         -
# 12     GO:0001676,GO:0003674,GO:0003824,GO:0004467,GO...  6.2.1.12
# ...                                                  ...       ...
# 14149                                                  -         -
# 14151  GO:0000166,GO:0000287,GO:0003674,GO:0003824,GO...   3.6.3.1
# 14154                                                NaN       NaN
# 14162                                                NaN       NaN
# 14163                                                NaN       NaN
#
#                    KEGG_ko                                       KEGG_Pathway  \
# 4                        -                                                  -
# 5      ko:K17352,ko:K17353                                                  -
# 6                        -                                                  -
# 10               ko:K16733                                                  -
# 12               ko:K01904  ko00130,ko00360,ko00940,ko01100,ko01110,map001...
# ...                    ...                                                ...
# 14149                    -                                                  -
# 14151            ko:K01530                                                  -
# 14154                  NaN                                                NaN
# 14162                  NaN                                                NaN
# 14163                  NaN                                                NaN
#
#       COG_category                                         eggNOG_OGs  \
# 4                Z  COG4886@1|root,KOG0532@2759|Eukaryota,38HCP@33...
# 5                S  KOG3882@1|root,KOG3882@2759|Eukaryota,39VAJ@33...
# 6                T  KOG0032@1|root,KOG0032@2759|Eukaryota,38G5X@33...
# 10               T  KOG3564@1|root,KOG3564@2759|Eukaryota,38ECX@33...
# 12               I  COG0318@1|root,KOG1176@2759|Eukaryota,38D90@33...
# ...            ...                                                ...
# 14149            L  COG0507@1|root,2S7Z5@2759|Eukaryota,3AB8Y@3315...
# 14151            P  COG0474@1|root,KOG0206@2759|Eukaryota,38BZ2@33...
# 14154          NaN                                                NaN
# 14162          NaN                                                NaN
# 14163          NaN                                                NaN
#
#            padj_safe neglog10_padj significant   label
# 4       1.373292e-28     27.862237        True      g7
# 5       4.975412e-52     51.303171        True      g8
# 6       2.241651e-15     14.649432        True      g9
# 10      3.512616e-86     85.454369        True     g13
# 12     6.566061e-145    144.182695        True     g15
# ...              ...           ...         ...     ...
# 14149   4.128766e-06      5.384180        True  g33982
# 14151   2.542697e-05      4.594705        True  g34016
# 14154   5.724767e-06      5.242242        True  g34172
# 14162   2.009399e-09      8.696934        True  g34922
# 14163   5.052814e-12     11.296467        True  g35167
#
# [5061 rows x 28 columns]
