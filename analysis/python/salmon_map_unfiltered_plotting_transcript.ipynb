# %% [markdown]
# For the unfiltered annotations, using the whole genome decoys

# %% [markdown]
# Load packages

# %%
import numpy as np
import pandas as pd
import plotly.express as px

from sklearn.decomposition import PCA

# %% [markdown]
# Load the datasets created in R

# %%
norm_counts = pd.read_csv("C:/Users/Sebas/OneDrive/Dokument/Master courses/MASTER THESIS/R project-Master Thesis/salmon_mapping_WG_unfiltered_normalized_counts_transcript.csv", index_col=0)
norm_counts
# Out:
#            ERR12356072  ERR12383247  ERR12383248  ERR12383249  ERR12383250  \
# g2.t1         8.129899     8.284848     8.408147     9.117746     8.659495
# g3.t1         7.480861     7.382536     7.812620     7.564934     8.114536
# g4.t1         7.836157     7.843106     7.803180     7.399427     7.426558
# g6.t1         8.761335     9.132528     8.588757     8.249145     8.549491
# g7.t1         7.203988     7.416068     7.448173     6.903426     6.811838
# ...                ...          ...          ...          ...          ...
# g34647.t1     5.692912     6.087677     5.692912     5.692912     5.692912
# g34695.t1     6.246748     6.307513     6.073154     6.216148     6.234186
# g34843.t1     6.310487     6.611560     6.707736     6.731566     6.409326
# g34922.t1     6.117110     6.099372     6.087652     6.152211     6.108180
# g35167.t1     6.142086     6.188158     6.605676     6.657287     6.281997
#
#            ERR12383251  ERR12383252  ERR12383253  ERR12383254  ERR12383255  \
# g2.t1         9.336525     8.051405     8.270330     8.336038     8.929309
# g3.t1         7.909752     7.251080     7.802250     7.534749     7.737689
# g4.t1         7.396362     7.780598     7.678734     7.912164     7.390930
# g6.t1         8.430607     9.088692     8.811586     9.001125     8.598133
# g7.t1         6.754500     7.617900     7.623725     7.543040     6.571117
# ...                ...          ...          ...          ...          ...
# g34647.t1     5.692912     6.167451     6.583203     5.692912     5.692912
# g34695.t1     6.154199     6.319587     6.298457     6.303248     6.070115
# g34843.t1     6.903030     6.491504     6.329179     6.455731     6.785361
# g34922.t1     6.472065     6.149797     5.932495     6.139003     5.692912
# g35167.t1     6.677767     6.337042     6.402483     6.825681     6.069784
#
#            ...  ERR12383308  ERR12383309  ERR12383310  ERR12383311  \
# g2.t1      ...     8.644707     8.369838     8.578802     7.984018
# g3.t1      ...     7.151856     7.421950     7.052821     6.590366
# g4.t1      ...     7.633890     7.656060     7.656589     7.810558
# g6.t1      ...     8.424863     8.436465     8.672603     8.916667
# g7.t1      ...     7.460846     6.905701     6.788624     7.522346
# ...        ...          ...          ...          ...          ...
# g34647.t1  ...     7.513129     7.529272     7.354984     6.872957
# g34695.t1  ...     6.789492     6.425299     6.291683     6.288435
# g34843.t1  ...     6.178036     5.855716     6.054100     6.535329
# g34922.t1  ...     7.079834     6.348490     6.173850     6.170508
# g35167.t1  ...     7.760007     6.334108     6.256313     6.320887
#
#            ERR12383312  ERR12383313  ERR12383314  ERR12383315  ERR12383316  \
# g2.t1         8.101248     8.529324     8.073392     8.378259     8.446727
# g3.t1         6.849961     6.930427     6.986943     7.957271     8.099311
# g4.t1         7.830106     7.710783     7.727986     7.385877     7.444632
# g6.t1         9.129104     9.152394     9.098354     8.485703     8.232946
# g7.t1         7.256477     7.281250     7.436314     7.269236     7.218957
# ...                ...          ...          ...          ...          ...
# g34647.t1     7.308291     7.193837     7.253189     5.692912     5.692912
# g34695.t1     6.237288     6.370531     6.373422     6.339642     6.035832
# g34843.t1     5.988995     5.995701     6.328147     6.948478     6.608368
# g34922.t1     5.961709     6.115189     6.129868     6.606995     5.692912
# g35167.t1     6.253035     6.105399     5.999017     7.782665     6.771256
#
#            ERR12383317
# g2.t1         9.133422
# g3.t1         7.785117
# g4.t1         6.946655
# g6.t1         8.143929
# g7.t1         7.023045
# ...                ...
# g34647.t1     6.090770
# g34695.t1     6.036098
# g34843.t1     6.641347
# g34922.t1     6.087392
# g35167.t1     7.089248
#
# [14163 rows x 70 columns]

# %%
#Metadata
metadata = pd.read_csv("C:/Users/Sebas/OneDrive/Dokument/Master courses/MASTER THESIS/R project-Master Thesis/dominance_meta_corrected_outlier_corrected.csv")

#make sure order matches norm_counts
metadata = metadata.set_index('Run')
metadata = metadata.reindex(norm_counts.columns)
# Now Run is the index, and metadata is aligned with counts
print("Metadata index (samples):", metadata.index[:5].tolist())
print("Counts columns:", norm_counts.columns[:5].tolist())
print("Match?", all(metadata.index == norm_counts.columns))
metadata
# Out:
# Metadata index (samples): ['ERR12356072', 'ERR12383247', 'ERR12383248', 'ERR12383249', 'ERR12383250']
# Counts columns: ['ERR12356072', 'ERR12383247', 'ERR12383248', 'ERR12383249', 'ERR12383250']
# Match? True
#                    Bases  BioProject       BioSample   Experiment  \
# ERR12356072  21027960416  PRJEB70958  SAMEA114860228  ERX11733017
# ERR12383247  14794943760  PRJEB70958  SAMEA114860213  ERX11759665
# ERR12383248  15610248328  PRJEB70958  SAMEA114860214  ERX11759666
# ERR12383249   9412089720  PRJEB70958  SAMEA114860215  ERX11759667
# ERR12383250   9959631122  PRJEB70958  SAMEA114860216  ERX11759668
# ...                  ...         ...             ...          ...
# ERR12383313  27406244206  PRJEB70958  SAMEA114860279  ERX11759731
# ERR12383314  13458064958  PRJEB70958  SAMEA114860280  ERX11759732
# ERR12383315  11890141660  PRJEB70958  SAMEA114860281  ERX11759733
# ERR12383316  13692674262  PRJEB70958  SAMEA114860282  ERX11759734
# ERR12383317  14658478416  PRJEB70958  SAMEA114860283  ERX11759735
#
#                                          sample_name         TF ID Sample ID  \
# ERR12356072  Sample 1 males genotype BA heterozygote  TF2581-10-e3     10e 3
# ERR12383247  Sample 1 females genotype AA homozygote     TF2581-11        11
# ERR12383248  Sample 2 females genotype AA homozygote     TF2581-12        12
# ERR12383249  Sample 3 females genotype AA homozygote     TF2581-13        13
# ERR12383250    Sample 1 males genotype AA homozygote  TF2581-14-e2     14e 2
# ...                                              ...           ...       ...
# ERR12383313  Sample 1 females genotype FF homozygote     TF2581-71        71
# ERR12383314  Sample 2 females genotype FF homozygote     TF2581-72        72
# ERR12383315  Sample 3 females genotype FF homozygote      TF2581-7         7
# ERR12383316    Sample 1 males genotype FF homozygote      TF2581-8         8
# ERR12383317    Sample 2 males genotype FF homozygote     TF2581-9e        9e
#
#                              Cross  Family Sex  \
# ERR12356072  13:20 (M) + 42:13 (F)  2,3,4,   F
# ERR12383247  13:20 (M) + 42:13 (F)  2,3,4,   F
# ERR12383248  13:20 (M) + 42:13 (F)  2,3,4,   F
# ERR12383249  42:13 (M) + 13:20 (F)   1,4,8   M
# ERR12383250  42:13 (M) + 13:20 (F)   1,4,8   M
# ...                            ...     ...  ..
# ERR12383313            4:18 + 4:18   2,6,9   F
# ERR12383314            4:18 + 4:18   2,6,9   F
# ERR12383315  13:20 (M) + 42:13 (F)  2,3,4,   M
# ERR12383316  13:20 (M) + 42:13 (F)  2,3,4,   M
# ERR12383317  13:20 (M) + 42:13 (F)  2,3,4,   M
#
#                              original_fastq_name_R1  \
# ERR12356072  TF-2581-10-e3_S67_L001_R1_001.fastq.gz
# ERR12383247      TF-2581-11_S9_L001_R1_001.fastq.gz
# ERR12383248     TF-2581-12_S10_L001_R1_001.fastq.gz
# ERR12383249     TF-2581-13_S11_L001_R1_001.fastq.gz
# ERR12383250  TF-2581-14-e2_S68_L001_R1_001.fastq.gz
# ...                                             ...
# ERR12383313     TF-2581-71_S59_L001_R1_001.fastq.gz
# ERR12383314     TF-2581-72_S60_L001_R1_001.fastq.gz
# ERR12383315       TF-2581-7_S7_L001_R1_001.fastq.gz
# ERR12383316       TF-2581-8_S8_L001_R1_001.fastq.gz
# ERR12383317     TF-2581-9e_S61_L001_R1_001.fastq.gz
#
#                              original_fastq_name_R2  \
# ERR12356072  TF-2581-10-e3_S67_L001_R2_001.fastq.gz
# ERR12383247      TF-2581-11_S9_L001_R2_001.fastq.gz
# ERR12383248     TF-2581-12_S10_L001_R2_001.fastq.gz
# ERR12383249     TF-2581-13_S11_L001_R2_001.fastq.gz
# ERR12383250  TF-2581-14-e2_S68_L001_R2_001.fastq.gz
# ...                                             ...
# ERR12383313     TF-2581-71_S59_L001_R2_001.fastq.gz
# ERR12383314     TF-2581-72_S60_L001_R2_001.fastq.gz
# ERR12383315       TF-2581-7_S7_L001_R2_001.fastq.gz
# ERR12383316       TF-2581-8_S8_L001_R2_001.fastq.gz
# ERR12383317     TF-2581-9e_S61_L001_R2_001.fastq.gz
#
#                                                Notes
# ERR12356072                                      NaN
# ERR12383247                                      NaN
# ERR12383248                                      NaN
# ERR12383249                                      NaN
# ERR12383250                                      NaN
# ...                                              ...
# ERR12383313  Had TF ID: TF2581-70, and Sample ID: 71
# ERR12383314  Had TF ID: TF2581-71, and Sample ID: 72
# ERR12383315                                      NaN
# ERR12383316                                      NaN
# ERR12383317                                      NaN
#
# [70 rows x 13 columns]

# %%
# create transpose
vst_t = norm_counts.T

pca = PCA(n_components=2)
pca_scores = pca.fit_transform(vst_t)

pca_df = metadata.copy()
pca_df['PC1'] = pca_scores[:,0]
pca_df['PC2'] = pca_scores[:,1]

# Explained variance
pc1_var = pca.explained_variance_ratio_[0] * 100
pc2_var = pca.explained_variance_ratio_[1] * 100

# Define your own color mapping
color_map = {'M': 'blue', 'F': 'red'}  

fig = px.scatter(
    pca_df,
    x='PC1',
    y='PC2',
    color='Sex',  
    color_discrete_map=color_map,          
    hover_name=pca_df.index,
    title=f"Male vs. Female PCA of VST-normalized counts"
)

fig.update_layout(
    xaxis_title=f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% var)",
    yaxis_title=f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% var)",
)
fig.show()

# %% [markdown]
# Volcano Plot

# %%
results_full_annot = pd.read_csv("C:/Users/Sebas/OneDrive/Dokument/Master courses/MASTER THESIS/R project-Master Thesis/salmon_transcript_level_sex_results.csv", float_precision='legacy')
results_full_annot
# Out:
#          baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0      248.481330        0.695139  0.131165   5.299723  1.159787e-07
# 1       92.720805        0.655798  0.169729   3.863801  1.116362e-04
# 2      136.058184       -0.621273  0.178646  -3.477686  5.057627e-04
# 3      381.089680       -0.916680  0.069653 -13.160737  1.476380e-39
# 4       70.720849       -1.043030  0.092963 -11.219877  3.257247e-29
# ...           ...             ...       ...        ...           ...
# 14158   10.439360        0.157161  1.106806   0.141995  8.870838e-01
# 14159   10.043810        0.631194  0.230476   2.738654  6.169119e-03
# 14160   20.288779        0.379406  0.210595   1.801590  7.160996e-02
# 14161    8.273471        2.235411  0.365535   6.115445  9.628801e-10
# 14162   19.119736        2.376713  0.338257   7.026353  2.120017e-12
#
#                padj transcript_id gene_id     seqname     start  ...  \
# 0      2.237715e-07         g2.t1      g2  utg000001l  220384.0  ...
# 1      1.811354e-04         g3.t1      g3  utg000001l  227675.0  ...
# 2      7.805558e-04         g4.t1      g4  utg000001l  245866.0  ...
# 3      8.463782e-39         g6.t1      g6  utg000001l  263441.0  ...
# 4      1.393012e-28         g7.t1      g7  utg000001l  371755.0  ...
# ...             ...           ...     ...         ...       ...  ...
# 14158  8.994062e-01     g34647.t1  g34647  utg003542l   22333.0  ...
# 14159  8.688554e-03     g34695.t1  g34695  utg003603l       1.0  ...
# 14160  8.890032e-02     g34843.t1  g34843  utg003648l    5656.0  ...
# 14161  2.063627e-09     g34922.t1  g34922  utg003714l       1.0  ...
# 14162  5.090628e-12     g35167.t1  g35167  utg003885l       1.0  ...
#
#                  HOG         OG Gene.Tree.Parent.Clade  \
# 0      N0.HOG0012111  OG0011460                     n0
# 1      N0.HOG0004052  OG0003481                     n0
# 2      N0.HOG0004826  OG0004221                     n0
# 3      N0.HOG0015574  OG0014921                     n0
# 4      N0.HOG0010167  OG0009526                     n0
# ...              ...        ...                    ...
# 14158  N0.HOG0001989  OG0001593                     n0
# 14159            NaN        NaN                    NaN
# 14160  N0.HOG0012740  OG0012089                     n0
# 14161  N0.HOG0000406  OG0000247                     n0
# 14162            NaN        NaN                    NaN
#
#                                 PFAMs  \
# 0                                COX8
# 1          PX,Pkinase,Pkinase_Tyr,WH2
# 2      Porphobil_deam,Porphobil_deamC
# 3                                THAP
# 4                            CH,LRR_8
# ...                               ...
# 14158           LRR_5,LRR_8,TIR,TIR_2
# 14159                  Staufen_C,dsrm
# 14160                             NaN
# 14161                             NaN
# 14162                             NaN
#
#                                                      GOs        EC  \
# 0                                                      -         -
# 1      GO:0003674,GO:0005488,GO:0005515,GO:0005543,GO...  3.1.26.5
# 2      GO:0001101,GO:0001666,GO:0003674,GO:0003824,GO...  2.5.1.61
# 3                                                      -         -
# 4      GO:0002682,GO:0002683,GO:0002685,GO:0002686,GO...         -
# ...                                                  ...       ...
# 14158                                                  -         -
# 14159  GO:0000003,GO:0000578,GO:0000932,GO:0001709,GO...         -
# 14160                                                NaN       NaN
# 14161                                                NaN       NaN
# 14162                                                NaN       NaN
#
#                    KEGG_ko                                       KEGG_Pathway  \
# 0                ko:K02273  ko00190,ko01100,ko04260,ko04714,ko04932,ko0501...
# 1      ko:K14529,ko:K17543                                   ko03013,map03013
# 2                ko:K01749  ko00860,ko01100,ko01110,ko01120,map00860,map01...
# 3                        -                                                  -
# 4                        -                                                  -
# ...                    ...                                                ...
# 14158                    -                                                  -
# 14159            ko:K17597                                                  -
# 14160                  NaN                                                NaN
# 14161                  NaN                                                NaN
# 14162                  NaN                                                NaN
#
#       COG_category                                         eggNOG_OGs
# 0                I  2FBM0@1|root,2TCUK@2759|Eukaryota,398E5@33154|...
# 1              DUZ  KOG2101@1|root,KOG2101@2759|Eukaryota,396Y9@33...
# 2                H  COG0181@1|root,KOG2892@2759|Eukaryota,38D6W@33...
# 3                B                  2E6V3@1|root,2SDHR@2759|Eukaryota
# 4                Z  COG4886@1|root,KOG0532@2759|Eukaryota,38HCP@33...
# ...            ...                                                ...
# 14158            T  COG4886@1|root,KOG4641@2759|Eukaryota,39T87@33...
# 14159           KU  KOG3732@1|root,KOG3732@2759|Eukaryota,38HNW@33...
# 14160          NaN                                                NaN
# 14161          NaN                                                NaN
# 14162          NaN                                                NaN
#
# [14163 rows x 24 columns]

# %%
# Replace the zeros in padj with 1e-308 avoid log10 issues
results_full_annot["padj_safe"] = results_full_annot["padj"].replace(0, 1e-308).fillna(1)

# Add the negative log 10 padj for plotting
results_full_annot["neglog10_padj"] = -np.log10(results_full_annot["padj_safe"])


# Add significance to differentially expressed genes 
results_full_annot["significant"] = (
    (results_full_annot["padj"] < 0.05) &
    (results_full_annot["log2FoldChange"].abs() > 1)
)

# Add a label to the significant genes
results_full_annot["label"] = results_full_annot["gene_id"].where(results_full_annot["significant"], "")

results_full_annot
# Out:
#          baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0      248.481330        0.695139  0.131165   5.299723  1.159787e-07
# 1       92.720805        0.655798  0.169729   3.863801  1.116362e-04
# 2      136.058184       -0.621273  0.178646  -3.477686  5.057627e-04
# 3      381.089680       -0.916680  0.069653 -13.160737  1.476380e-39
# 4       70.720849       -1.043030  0.092963 -11.219877  3.257247e-29
# ...           ...             ...       ...        ...           ...
# 14158   10.439360        0.157161  1.106806   0.141995  8.870838e-01
# 14159   10.043810        0.631194  0.230476   2.738654  6.169119e-03
# 14160   20.288779        0.379406  0.210595   1.801590  7.160996e-02
# 14161    8.273471        2.235411  0.365535   6.115445  9.628801e-10
# 14162   19.119736        2.376713  0.338257   7.026353  2.120017e-12
#
#                padj transcript_id gene_id     seqname     start  ...  \
# 0      2.237715e-07         g2.t1      g2  utg000001l  220384.0  ...
# 1      1.811354e-04         g3.t1      g3  utg000001l  227675.0  ...
# 2      7.805558e-04         g4.t1      g4  utg000001l  245866.0  ...
# 3      8.463782e-39         g6.t1      g6  utg000001l  263441.0  ...
# 4      1.393012e-28         g7.t1      g7  utg000001l  371755.0  ...
# ...             ...           ...     ...         ...       ...  ...
# 14158  8.994062e-01     g34647.t1  g34647  utg003542l   22333.0  ...
# 14159  8.688554e-03     g34695.t1  g34695  utg003603l       1.0  ...
# 14160  8.890032e-02     g34843.t1  g34843  utg003648l    5656.0  ...
# 14161  2.063627e-09     g34922.t1  g34922  utg003714l       1.0  ...
# 14162  5.090628e-12     g35167.t1  g35167  utg003885l       1.0  ...
#
#                                                      GOs        EC  \
# 0                                                      -         -
# 1      GO:0003674,GO:0005488,GO:0005515,GO:0005543,GO...  3.1.26.5
# 2      GO:0001101,GO:0001666,GO:0003674,GO:0003824,GO...  2.5.1.61
# 3                                                      -         -
# 4      GO:0002682,GO:0002683,GO:0002685,GO:0002686,GO...         -
# ...                                                  ...       ...
# 14158                                                  -         -
# 14159  GO:0000003,GO:0000578,GO:0000932,GO:0001709,GO...         -
# 14160                                                NaN       NaN
# 14161                                                NaN       NaN
# 14162                                                NaN       NaN
#
#                    KEGG_ko                                       KEGG_Pathway  \
# 0                ko:K02273  ko00190,ko01100,ko04260,ko04714,ko04932,ko0501...
# 1      ko:K14529,ko:K17543                                   ko03013,map03013
# 2                ko:K01749  ko00860,ko01100,ko01110,ko01120,map00860,map01...
# 3                        -                                                  -
# 4                        -                                                  -
# ...                    ...                                                ...
# 14158                    -                                                  -
# 14159            ko:K17597                                                  -
# 14160                  NaN                                                NaN
# 14161                  NaN                                                NaN
# 14162                  NaN                                                NaN
#
#       COG_category                                         eggNOG_OGs  \
# 0                I  2FBM0@1|root,2TCUK@2759|Eukaryota,398E5@33154|...
# 1              DUZ  KOG2101@1|root,KOG2101@2759|Eukaryota,396Y9@33...
# 2                H  COG0181@1|root,KOG2892@2759|Eukaryota,38D6W@33...
# 3                B                  2E6V3@1|root,2SDHR@2759|Eukaryota
# 4                Z  COG4886@1|root,KOG0532@2759|Eukaryota,38HCP@33...
# ...            ...                                                ...
# 14158            T  COG4886@1|root,KOG4641@2759|Eukaryota,39T87@33...
# 14159           KU  KOG3732@1|root,KOG3732@2759|Eukaryota,38HNW@33...
# 14160          NaN                                                NaN
# 14161          NaN                                                NaN
# 14162          NaN                                                NaN
#
#           padj_safe neglog10_padj significant   label
# 0      2.237715e-07      6.650195       False
# 1      1.811354e-04      3.741997       False
# 2      7.805558e-04      3.107596       False
# 3      8.463782e-39     38.072436       False
# 4      1.393012e-28     27.856045        True      g7
# ...             ...           ...         ...     ...
# 14158  8.994062e-01      0.046044       False
# 14159  8.688554e-03      2.061053       False
# 14160  8.890032e-02      1.051097       False
# 14161  2.063627e-09      8.685369        True  g34922
# 14162  5.090628e-12     11.293229        True  g35167
#
# [14163 rows x 28 columns]

# %%
fig = px.scatter(
    results_full_annot,
    x="log2FoldChange",
    y="neglog10_padj",
    hover_name="transcript_id",
    hover_data=["padj", "HOG", "PFAMs"],  # Use the columns that already exist
    color="significant",
    color_discrete_map={True: "red", False: "blue"},
    title="Volcano Plot (Male vs Female Transcript Expression)"
)

fig.update_traces(textposition='top center', textfont_size=8)

fig.update_layout(
    xaxis_title="log2 Fold Change (male vs female)",
    yaxis_title="-log10(padj (FDR))",
)

# Horizontal FDR=0.05 cutoff
padj_cut = -np.log10(0.05)

fig.add_hline(
    y=padj_cut,
    line_dash="dash",
    line_color="grey",
    annotation_text="padj = 0.05",
    annotation_position="bottom right"
)

# Vertical log2FC cutoffs
fig.add_vline(
    x=-1,
    line_dash="dash",
    line_color="grey",
    annotation_text="log2FC = -1",
    annotation_position="top left"
)
fig.add_vline(
    x=1,
    line_dash="dash",
    line_color="grey",
    annotation_text="log2FC = 1",
    annotation_position="top right"
)

fig.show()


#DE genes
sig_counts = results_full_annot["significant"].sum()
higher_in_m = ((results_full_annot["significant"]) & 
               (results_full_annot["log2FoldChange"] > 0)).sum()
higher_in_f = ((results_full_annot["significant"]) & 
               (results_full_annot["log2FoldChange"] < 0)).sum()

print(f"Total significant transcripts: {sig_counts}")
print(f"Higher in males: {higher_in_m}")
print(f"Higher in females: {higher_in_f}")
# Out:
# Total significant transcripts: 5064
# Higher in males: 3193
# Higher in females: 1871

# %% [markdown]
# Significant Transcripts

# %%
sig_transcripts = results_full_annot[results_full_annot["significant"]]

sig_transcripts
# Out:
#          baseMean  log2FoldChange     lfcSE       stat         pvalue  \
# 4       70.720849       -1.043030  0.092963 -11.219877   3.257247e-29
# 5      475.786092        1.109162  0.072364  15.327494   5.009434e-53
# 6       97.179194        1.439896  0.178985   8.044775   8.640372e-16
# 10     237.584265       -3.903205  0.196943 -19.818938   2.043780e-87
# 12     961.157517       -4.356897  0.168991 -25.781900  1.415191e-146
# ...           ...             ...       ...        ...            ...
# 14148    8.769712        1.532600  0.325086   4.714439   2.423772e-06
# 14150   15.736716       -1.550344  0.357538  -4.336164   1.449910e-05
# 14153   33.906475        1.466745  0.315250   4.652642   3.277086e-06
# 14161    8.273471        2.235411  0.365535   6.115445   9.628801e-10
# 14162   19.119736        2.376713  0.338257   7.026353   2.120017e-12
#
#                 padj transcript_id gene_id     seqname     start  ...  \
# 4       1.393012e-28         g7.t1      g7  utg000001l  371755.0  ...
# 5       4.086036e-52         g8.t1      g8  utg000001l  510966.0  ...
# 6       2.376606e-15         g9.t1      g9  utg000001l  531498.0  ...
# 10      3.577247e-86        g13.t1     g13  utg000001l  666271.0  ...
# 12     8.906272e-145        g15.t1     g15  utg000001l  789435.0  ...
# ...              ...           ...     ...         ...       ...  ...
# 14148   4.359279e-06     g33982.t1  g33982  utg003197l       1.0  ...
# 14150   2.494621e-05     g34016.t1  g34016  utg003227l       1.0  ...
# 14153   5.843538e-06     g34172.t1  g34172  utg003311l       1.0  ...
# 14161   2.063627e-09     g34922.t1  g34922  utg003714l       1.0  ...
# 14162   5.090628e-12     g35167.t1  g35167  utg003885l       1.0  ...
#
#                                                      GOs        EC  \
# 4      GO:0002682,GO:0002683,GO:0002685,GO:0002686,GO...         -
# 5      GO:0005575,GO:0005623,GO:0005886,GO:0005887,GO...         -
# 6      GO:0003674,GO:0005488,GO:0005509,GO:0043167,GO...         -
# 10     GO:0000003,GO:0000022,GO:0000070,GO:0000226,GO...         -
# 12     GO:0001676,GO:0003674,GO:0003824,GO:0004467,GO...  6.2.1.12
# ...                                                  ...       ...
# 14148                                                  -         -
# 14150  GO:0000166,GO:0000287,GO:0003674,GO:0003824,GO...   3.6.3.1
# 14153                                                NaN       NaN
# 14161                                                NaN       NaN
# 14162                                                NaN       NaN
#
#                    KEGG_ko                                       KEGG_Pathway  \
# 4                        -                                                  -
# 5      ko:K17352,ko:K17353                                                  -
# 6                        -                                                  -
# 10               ko:K16733                                                  -
# 12               ko:K01904  ko00130,ko00360,ko00940,ko01100,ko01110,map001...
# ...                    ...                                                ...
# 14148                    -                                                  -
# 14150            ko:K01530                                                  -
# 14153                  NaN                                                NaN
# 14161                  NaN                                                NaN
# 14162                  NaN                                                NaN
#
#       COG_category                                         eggNOG_OGs  \
# 4                Z  COG4886@1|root,KOG0532@2759|Eukaryota,38HCP@33...
# 5                S  KOG3882@1|root,KOG3882@2759|Eukaryota,39VAJ@33...
# 6                T  KOG0032@1|root,KOG0032@2759|Eukaryota,38G5X@33...
# 10               T  KOG3564@1|root,KOG3564@2759|Eukaryota,38ECX@33...
# 12               I  COG0318@1|root,KOG1176@2759|Eukaryota,38D90@33...
# ...            ...                                                ...
# 14148            L  COG0507@1|root,2S7Z5@2759|Eukaryota,3AB8Y@3315...
# 14150            P  COG0474@1|root,KOG0206@2759|Eukaryota,38BZ2@33...
# 14153          NaN                                                NaN
# 14161          NaN                                                NaN
# 14162          NaN                                                NaN
#
#            padj_safe neglog10_padj significant   label
# 4       1.393012e-28     27.856045        True      g7
# 5       4.086036e-52     51.388698        True      g8
# 6       2.376606e-15     14.624043        True      g9
# 10      3.577247e-86     85.446451        True     g13
# 12     8.906272e-145    144.050304        True     g15
# ...              ...           ...         ...     ...
# 14148   4.359279e-06      5.360585        True  g33982
# 14150   2.494621e-05      4.602995        True  g34016
# 14153   5.843538e-06      5.233324        True  g34172
# 14161   2.063627e-09      8.685369        True  g34922
# 14162   5.090628e-12     11.293229        True  g35167
#
# [5064 rows x 28 columns]
