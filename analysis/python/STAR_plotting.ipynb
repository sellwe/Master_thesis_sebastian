# %%
import numpy as np
import pandas as pd
import plotly.express as px

from sklearn.decomposition import PCA

# %% [markdown]
# Load datasets created in R

# %%
norm_counts = pd.read_csv("C:/Users/Sebas/OneDrive/Dokument/Master courses/MASTER THESIS/R project-Master Thesis/STAR_normalized_counts.csv", index_col=0)
norm_counts
# Out:
#            ERR12356072  ERR12383247  ERR12383248  ERR12383249  ERR12383250  \
# g10.t1        8.871424     8.979602     8.848643     9.693969     9.602214
# g1000.t1     11.136752    10.668892    10.977305    11.014044    11.372183
# g10001.t1     5.146178     4.991529     5.254029     5.829863     5.656432
# g10006.t1     5.211881     4.853250     4.908934     4.776783     4.753735
# g10007.t1     4.607671     5.049680     5.171981     5.348631     5.492987
# ...                ...          ...          ...          ...          ...
# g9975.t1      4.371564     4.765464     4.371564     4.371564     4.910479
# g998.t1       5.664929     5.613234     5.652933     5.423728     6.551751
# g999.t1       5.406322     5.494943     5.459811     5.493020     5.129400
# g9991.t1      5.073725     5.152253     4.837606     5.266238     5.129400
# g9993.t1      4.705099     5.049680     4.752633     4.371564     5.365858
#
#            ERR12383251  ERR12383252  ERR12383253  ERR12383254  ERR12383255  \
# g10.t1        9.227561     8.992820     8.623803     8.521223     8.974701
# g1000.t1     10.782349    10.468458    11.309173    10.455374    11.325020
# g10001.t1     5.368146     5.141727     4.996283     4.371564     5.517299
# g10006.t1     4.989320     4.952144     4.882958     4.371564     5.285956
# g10007.t1     5.580824     4.983098     5.348305     4.926541     4.785946
# ...                ...          ...          ...          ...          ...
# g9975.t1      5.165147     4.760060     4.734115     5.321496     4.955608
# g998.t1       6.412509     4.983098     5.212122     5.639898     5.084488
# g999.t1       6.341190     5.583195     5.569556     5.394670     5.285956
# g9991.t1      4.989320     4.884346     4.371564     4.926541     4.785946
# g9993.t1      6.128434     5.093029     5.091096     5.151727     6.160250
#
#            ...  ERR12383308  ERR12383309  ERR12383310  ERR12383311  \
# g10.t1     ...     9.752090     9.437695     9.902856     9.104431
# g1000.t1   ...    10.739684    10.970993    10.646826    10.494464
# g10001.t1  ...     5.774991     5.178502     5.321486     5.127561
# g10006.t1  ...     5.053184     5.288161     5.525130     5.062978
# g10007.t1  ...     6.168404     6.184462     5.964588     5.547775
# ...        ...          ...          ...          ...          ...
# g9975.t1   ...     4.371564     4.736189     5.049213     4.371564
# g998.t1    ...     6.218827     6.226766     6.079487     4.991147
# g999.t1    ...     5.700080     5.964740     5.814234     5.918507
# g9991.t1   ...     5.774991     5.216821     5.049213     4.811345
# g9993.t1   ...     4.714743     4.371564     4.371564     5.127561
#
#            ERR12383312  ERR12383313  ERR12383314  ERR12383315  ERR12383316  \
# g10.t1        9.096976     9.189748     8.951481     9.309402     9.254180
# g1000.t1     10.199741    10.245875    10.335804    11.495664    11.880153
# g10001.t1     5.112480     4.962439     4.849412     6.341575     5.457855
# g10006.t1     5.783602     5.609405     5.993282     4.371564     4.823738
# g10007.t1     5.716067     5.516350     5.733600     5.306210     5.082237
# ...                ...          ...          ...          ...          ...
# g9975.t1      4.371564     4.866950     4.986619     4.968804     4.691951
# g998.t1       5.809475     5.905866     5.757732     8.479223     5.958536
# g999.t1       5.859465     5.596638     6.012467     5.609261     5.579385
# g9991.t1      5.328406     5.259848     4.762316     5.392011     4.823738
# g9993.t1      4.664874     4.371564     4.648288     4.795373     5.457855
#
#            ERR12383317
# g10.t1        8.929236
# g1000.t1     11.632454
# g10001.t1     5.459367
# g10006.t1     4.371564
# g10007.t1     5.178285
# ...                ...
# g9975.t1      5.232436
# g998.t1       6.488161
# g999.t1       5.607087
# g9991.t1      4.679877
# g9993.t1      5.705031
#
# [14491 rows x 70 columns]

# %%
#Metadata
metadata = pd.read_csv("C:/Users/Sebas/OneDrive/Dokument/Master courses/MASTER THESIS/R project-Master Thesis/dominance_meta_corrected_outlier_corrected.csv")

#make sure order matches norm_counts
metadata = metadata.set_index('Run')
metadata = metadata.reindex(norm_counts.columns)
# Now Run is the index, and metadata is aligned with counts
print("Metadata index (samples):", metadata.index[:5].tolist())
print("Counts columns:", norm_counts.columns[:5].tolist())
print("Match?", all(metadata.index == norm_counts.columns))
metadata
# Out:
# Metadata index (samples): ['ERR12356072', 'ERR12383247', 'ERR12383248', 'ERR12383249', 'ERR12383250']
# Counts columns: ['ERR12356072', 'ERR12383247', 'ERR12383248', 'ERR12383249', 'ERR12383250']
# Match? True
#                    Bases  BioProject       BioSample   Experiment  \
# ERR12356072  21027960416  PRJEB70958  SAMEA114860228  ERX11733017
# ERR12383247  14794943760  PRJEB70958  SAMEA114860213  ERX11759665
# ERR12383248  15610248328  PRJEB70958  SAMEA114860214  ERX11759666
# ERR12383249   9412089720  PRJEB70958  SAMEA114860215  ERX11759667
# ERR12383250   9959631122  PRJEB70958  SAMEA114860216  ERX11759668
# ...                  ...         ...             ...          ...
# ERR12383313  27406244206  PRJEB70958  SAMEA114860279  ERX11759731
# ERR12383314  13458064958  PRJEB70958  SAMEA114860280  ERX11759732
# ERR12383315  11890141660  PRJEB70958  SAMEA114860281  ERX11759733
# ERR12383316  13692674262  PRJEB70958  SAMEA114860282  ERX11759734
# ERR12383317  14658478416  PRJEB70958  SAMEA114860283  ERX11759735
#
#                                          sample_name         TF ID Sample ID  \
# ERR12356072  Sample 1 males genotype BA heterozygote  TF2581-10-e3     10e 3
# ERR12383247  Sample 1 females genotype AA homozygote     TF2581-11        11
# ERR12383248  Sample 2 females genotype AA homozygote     TF2581-12        12
# ERR12383249  Sample 3 females genotype AA homozygote     TF2581-13        13
# ERR12383250    Sample 1 males genotype AA homozygote  TF2581-14-e2     14e 2
# ...                                              ...           ...       ...
# ERR12383313  Sample 1 females genotype FF homozygote     TF2581-71        71
# ERR12383314  Sample 2 females genotype FF homozygote     TF2581-72        72
# ERR12383315  Sample 3 females genotype FF homozygote      TF2581-7         7
# ERR12383316    Sample 1 males genotype FF homozygote      TF2581-8         8
# ERR12383317    Sample 2 males genotype FF homozygote     TF2581-9e        9e
#
#                              Cross  Family Sex  \
# ERR12356072  13:20 (M) + 42:13 (F)  2,3,4,   F
# ERR12383247  13:20 (M) + 42:13 (F)  2,3,4,   F
# ERR12383248  13:20 (M) + 42:13 (F)  2,3,4,   F
# ERR12383249  42:13 (M) + 13:20 (F)   1,4,8   M
# ERR12383250  42:13 (M) + 13:20 (F)   1,4,8   M
# ...                            ...     ...  ..
# ERR12383313            4:18 + 4:18   2,6,9   F
# ERR12383314            4:18 + 4:18   2,6,9   F
# ERR12383315  13:20 (M) + 42:13 (F)  2,3,4,   M
# ERR12383316  13:20 (M) + 42:13 (F)  2,3,4,   M
# ERR12383317  13:20 (M) + 42:13 (F)  2,3,4,   M
#
#                              original_fastq_name_R1  \
# ERR12356072  TF-2581-10-e3_S67_L001_R1_001.fastq.gz
# ERR12383247      TF-2581-11_S9_L001_R1_001.fastq.gz
# ERR12383248     TF-2581-12_S10_L001_R1_001.fastq.gz
# ERR12383249     TF-2581-13_S11_L001_R1_001.fastq.gz
# ERR12383250  TF-2581-14-e2_S68_L001_R1_001.fastq.gz
# ...                                             ...
# ERR12383313     TF-2581-71_S59_L001_R1_001.fastq.gz
# ERR12383314     TF-2581-72_S60_L001_R1_001.fastq.gz
# ERR12383315       TF-2581-7_S7_L001_R1_001.fastq.gz
# ERR12383316       TF-2581-8_S8_L001_R1_001.fastq.gz
# ERR12383317     TF-2581-9e_S61_L001_R1_001.fastq.gz
#
#                              original_fastq_name_R2  \
# ERR12356072  TF-2581-10-e3_S67_L001_R2_001.fastq.gz
# ERR12383247      TF-2581-11_S9_L001_R2_001.fastq.gz
# ERR12383248     TF-2581-12_S10_L001_R2_001.fastq.gz
# ERR12383249     TF-2581-13_S11_L001_R2_001.fastq.gz
# ERR12383250  TF-2581-14-e2_S68_L001_R2_001.fastq.gz
# ...                                             ...
# ERR12383313     TF-2581-71_S59_L001_R2_001.fastq.gz
# ERR12383314     TF-2581-72_S60_L001_R2_001.fastq.gz
# ERR12383315       TF-2581-7_S7_L001_R2_001.fastq.gz
# ERR12383316       TF-2581-8_S8_L001_R2_001.fastq.gz
# ERR12383317     TF-2581-9e_S61_L001_R2_001.fastq.gz
#
#                                                Notes
# ERR12356072                                      NaN
# ERR12383247                                      NaN
# ERR12383248                                      NaN
# ERR12383249                                      NaN
# ERR12383250                                      NaN
# ...                                              ...
# ERR12383313  Had TF ID: TF2581-70, and Sample ID: 71
# ERR12383314  Had TF ID: TF2581-71, and Sample ID: 72
# ERR12383315                                      NaN
# ERR12383316                                      NaN
# ERR12383317                                      NaN
#
# [70 rows x 13 columns]

# %% [markdown]
# PCA Plot

# %%
# create transpose
vst_t = norm_counts.T

pca = PCA(n_components=2)
pca_scores = pca.fit_transform(vst_t)

pca_df = metadata.copy()
pca_df['PC1'] = pca_scores[:,0]
pca_df['PC2'] = pca_scores[:,1]

# Explained variance
pc1_var = pca.explained_variance_ratio_[0] * 100
pc2_var = pca.explained_variance_ratio_[1] * 100

# Define your own color mapping
color_map = {'M': 'blue', 'F': 'red'}  

fig = px.scatter(
    pca_df,
    x='PC1',
    y='PC2',
    color='Sex',  
    color_discrete_map=color_map,          
    hover_name=pca_df.index,
    title=f"Male vs. Female PCA of VST-normalized counts"
)

fig.update_layout(
    xaxis_title=f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% var)",
    yaxis_title=f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% var)",
)
fig.show()

# %% [markdown]
# Volcano plot

# %%
results_full_annot = pd.read_csv("C:/Users/Sebas/OneDrive/Dokument/Master courses/MASTER THESIS/R project-Master Thesis/STAR_featureCounts_deseq2_sex_results_fully_annotated.csv")
results_full_annot
# Out:
#           baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 0       456.100314        0.539079  0.130288  4.137586  3.509789e-05
# 1      1836.622862        0.664999  0.075707  8.783856  1.579635e-18
# 2         9.277403        1.333546  0.216804  6.150915  7.703709e-10
# 3         5.817209       -0.848525  0.467592 -1.814669  6.957478e-02
# 4         8.725202        0.915383  0.433734  2.110473  3.481764e-02
# ...            ...             ...       ...       ...           ...
# 14486     3.644762        1.053781  0.354595  2.971785  2.960737e-03
# 14487    65.202446        1.386473  0.283779  4.885748  1.030367e-06
# 14488    20.318618        0.332156  0.150204  2.211374  2.700997e-02
# 14489     5.285936        0.873696  0.343095  2.546516  1.088043e-02
# 14490     9.375622        0.551407  0.503868  1.094349  2.738021e-01
#
#                padj transcript_id gene_id     seqname    start  ...  \
# 0      5.845346e-05        g10.t1     g10  utg000001l   554496  ...
# 1      4.848653e-18      g1000.t1   g1000  utg000005l  5092168  ...
# 2      1.663951e-09     g10001.t1  g10001  utg000074l  8915422  ...
# 3      8.494466e-02     g10006.t1  g10006  utg000074l  9020033  ...
# 4      4.416126e-02     g10007.t1  g10007  utg000074l  9029095  ...
# ...             ...           ...     ...         ...      ...  ...
# 14486  4.238691e-03      g9975.t1   g9975  utg000074l  8597833  ...
# 14487  1.889289e-06       g998.t1    g998  utg000005l  4824834  ...
# 14488  3.473258e-02       g999.t1    g999  utg000005l  4837205  ...
# 14489  1.463958e-02      g9991.t1   g9991  utg000074l  8820390  ...
# 14490  3.069286e-01      g9993.t1   g9993  utg000074l  8847120  ...
#
#                  HOG         OG Gene.Tree.Parent.Clade  \
# 0      N0.HOG0002621  OG0002163                     n0
# 1      N0.HOG0004899  OG0004294                     n0
# 2      N0.HOG0024445  OG0023792                      -
# 3      N0.HOG0017991  OG0017338                     n0
# 4      N0.HOG0014231  OG0013579                     n0
# ...              ...        ...                    ...
# 14486  N0.HOG0004753  OG0004150                     n0
# 14487  N0.HOG0000290  OG0000170                     n0
# 14488  N0.HOG0007599  OG0006964                     n0
# 14489  N0.HOG0012813  OG0012161                     n0
# 14490  N0.HOG0000071  OG0000033                     n0
#
#                                          PFAMs  \
# 0      EF-hand_1,EF-hand_5,EF-hand_6,EF-hand_7
# 1                              Ribonuclease_T2
# 2                                    DDE_Tnp_4
# 3                                          NaN
# 4                                            -
# ...                                        ...
# 14486                                      NaN
# 14487                    Exo_endo_phos_2,RVT_1
# 14488                          Autophagy_act_C
# 14489                                DDE_Tnp_4
# 14490                        BESS,MADF_DNA_bdg
#
#                                                      GOs        EC    KEGG_ko  \
# 0      GO:0003674,GO:0005488,GO:0005509,GO:0043167,GO...         -          -
# 1      GO:0003674,GO:0003824,GO:0004518,GO:0004540,GO...  3.1.27.1  ko:K01166
# 2                                                      -         -          -
# 3                                                    NaN       NaN        NaN
# 4                                                      -         -          -
# ...                                                  ...       ...        ...
# 14486                                                NaN       NaN        NaN
# 14487                                                  -         -          -
# 14488  GO:0003674,GO:0003824,GO:0005575,GO:0005622,GO...         -  ko:K17888
# 14489                                                  -         -          -
# 14490                                                  -         -          -
#
#                                             KEGG_Pathway COG_category  \
# 0                                                      -            T
# 1                                                      -            A
# 2                                                      -            B
# 3                                                    NaN          NaN
# 4                                                      -            S
# ...                                                  ...          ...
# 14486                                                NaN          NaN
# 14487                                                  -            S
# 14488  ko04136,ko04138,ko04140,map04136,map04138,map0...            S
# 14489                                                  -            L
# 14490                                                  -            K
#
#                                               eggNOG_OGs
# 0      KOG0032@1|root,KOG0032@2759|Eukaryota,38G5X@33...
# 1      KOG1642@1|root,KOG1642@2759|Eukaryota,38KSQ@33...
# 2                  KOG4585@1|root,KOG4585@2759|Eukaryota
# 3                                                    NaN
# 4      2EV8V@1|root,2SX9Q@2759|Eukaryota,3ASV5@33154|...
# ...                                                  ...
# 14486                                                NaN
# 14487  KOG1075@1|root,KOG1075@2759|Eukaryota,3A0JU@33...
# 14488  KOG4741@1|root,KOG4741@2759|Eukaryota,39WIU@33...
# 14489  KOG4585@1|root,KOG4585@2759|Eukaryota,3A4U2@33...
# 14490  2E8EB@1|root,2SEWX@2759|Eukaryota,3AC3W@33154|...
#
# [14491 rows x 24 columns]

# %%
# Replace the zeros in padj with 1e-308 avoid log10 issues
results_full_annot["padj_safe"] = results_full_annot["padj"].replace(0, 1e-308).fillna(1)

# Add the negative log 10 padj for plotting
results_full_annot["neglog10_padj"] = -np.log10(results_full_annot["padj_safe"])


# Add significance to differentially expressed transcripts 
results_full_annot["significant"] = (
    (results_full_annot["padj"] < 0.05) &
    (results_full_annot["log2FoldChange"].abs() > 1)
)

# Add a label to the significant transcripts
results_full_annot["label"] = results_full_annot["transcript_id"].where(results_full_annot["significant"], "")

results_full_annot
# Out:
#           baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 0       456.100314        0.539079  0.130288  4.137586  3.509789e-05
# 1      1836.622862        0.664999  0.075707  8.783856  1.579635e-18
# 2         9.277403        1.333546  0.216804  6.150915  7.703709e-10
# 3         5.817209       -0.848525  0.467592 -1.814669  6.957478e-02
# 4         8.725202        0.915383  0.433734  2.110473  3.481764e-02
# ...            ...             ...       ...       ...           ...
# 14486     3.644762        1.053781  0.354595  2.971785  2.960737e-03
# 14487    65.202446        1.386473  0.283779  4.885748  1.030367e-06
# 14488    20.318618        0.332156  0.150204  2.211374  2.700997e-02
# 14489     5.285936        0.873696  0.343095  2.546516  1.088043e-02
# 14490     9.375622        0.551407  0.503868  1.094349  2.738021e-01
#
#                padj transcript_id gene_id     seqname    start  ...  \
# 0      5.845346e-05        g10.t1     g10  utg000001l   554496  ...
# 1      4.848653e-18      g1000.t1   g1000  utg000005l  5092168  ...
# 2      1.663951e-09     g10001.t1  g10001  utg000074l  8915422  ...
# 3      8.494466e-02     g10006.t1  g10006  utg000074l  9020033  ...
# 4      4.416126e-02     g10007.t1  g10007  utg000074l  9029095  ...
# ...             ...           ...     ...         ...      ...  ...
# 14486  4.238691e-03      g9975.t1   g9975  utg000074l  8597833  ...
# 14487  1.889289e-06       g998.t1    g998  utg000005l  4824834  ...
# 14488  3.473258e-02       g999.t1    g999  utg000005l  4837205  ...
# 14489  1.463958e-02      g9991.t1   g9991  utg000074l  8820390  ...
# 14490  3.069286e-01      g9993.t1   g9993  utg000074l  8847120  ...
#
#                                                      GOs        EC    KEGG_ko  \
# 0      GO:0003674,GO:0005488,GO:0005509,GO:0043167,GO...         -          -
# 1      GO:0003674,GO:0003824,GO:0004518,GO:0004540,GO...  3.1.27.1  ko:K01166
# 2                                                      -         -          -
# 3                                                    NaN       NaN        NaN
# 4                                                      -         -          -
# ...                                                  ...       ...        ...
# 14486                                                NaN       NaN        NaN
# 14487                                                  -         -          -
# 14488  GO:0003674,GO:0003824,GO:0005575,GO:0005622,GO...         -  ko:K17888
# 14489                                                  -         -          -
# 14490                                                  -         -          -
#
#                                             KEGG_Pathway COG_category  \
# 0                                                      -            T
# 1                                                      -            A
# 2                                                      -            B
# 3                                                    NaN          NaN
# 4                                                      -            S
# ...                                                  ...          ...
# 14486                                                NaN          NaN
# 14487                                                  -            S
# 14488  ko04136,ko04138,ko04140,map04136,map04138,map0...            S
# 14489                                                  -            L
# 14490                                                  -            K
#
#                                               eggNOG_OGs     padj_safe  \
# 0      KOG0032@1|root,KOG0032@2759|Eukaryota,38G5X@33...  5.845346e-05
# 1      KOG1642@1|root,KOG1642@2759|Eukaryota,38KSQ@33...  4.848653e-18
# 2                  KOG4585@1|root,KOG4585@2759|Eukaryota  1.663951e-09
# 3                                                    NaN  8.494466e-02
# 4      2EV8V@1|root,2SX9Q@2759|Eukaryota,3ASV5@33154|...  4.416126e-02
# ...                                                  ...           ...
# 14486                                                NaN  4.238691e-03
# 14487  KOG1075@1|root,KOG1075@2759|Eukaryota,3A0JU@33...  1.889289e-06
# 14488  KOG4741@1|root,KOG4741@2759|Eukaryota,39WIU@33...  3.473258e-02
# 14489  KOG4585@1|root,KOG4585@2759|Eukaryota,3A4U2@33...  1.463958e-02
# 14490  2E8EB@1|root,2SEWX@2759|Eukaryota,3AC3W@33154|...  3.069286e-01
#
#       neglog10_padj significant      label
# 0          4.233190       False
# 1         17.314379       False
# 2          8.778860        True  g10001.t1
# 3          1.070864       False
# 4          1.354959       False
# ...             ...         ...        ...
# 14486      2.372768        True   g9975.t1
# 14487      5.723702        True    g998.t1
# 14488      1.459263       False
# 14489      1.834471       False
# 14490      0.512963       False
#
# [14491 rows x 28 columns]

# %%
fig = px.scatter(
    results_full_annot,
    x="log2FoldChange",
    y="neglog10_padj",
    hover_name="transcript_id",
    hover_data=["padj", "HOG", "PFAMs"],  # Use the columns that already exist
    color="significant",
    color_discrete_map={True: "red", False: "blue"},
    title="Volcano Plot (Male vs Female Transcript Expression)"
)

fig.update_traces(textposition='top center', textfont_size=8)

fig.update_layout(
    xaxis_title="log2 Fold Change (male vs female)",
    yaxis_title="-log10(padj (FDR))",
)

# Horizontal FDR=0.05 cutoff
padj_cut = -np.log10(0.05)

fig.add_hline(
    y=padj_cut,
    line_dash="dash",
    line_color="grey",
    annotation_text="padj = 0.05",
    annotation_position="bottom right"
)

# Vertical log2FC cutoffs
fig.add_vline(
    x=-1,
    line_dash="dash",
    line_color="grey",
    annotation_text="log2FC = -1",
    annotation_position="top left"
)
fig.add_vline(
    x=1,
    line_dash="dash",
    line_color="grey",
    annotation_text="log2FC = 1",
    annotation_position="top right"
)

fig.show()


#DE transcripts
sig_counts = results_full_annot["significant"].sum()
higher_in_m = ((results_full_annot["significant"]) & 
               (results_full_annot["log2FoldChange"] > 0)).sum()
higher_in_f = ((results_full_annot["significant"]) & 
               (results_full_annot["log2FoldChange"] < 0)).sum()

print(f"Total significant transcripts: {sig_counts}")
print(f"Higher in males: {higher_in_m}")
print(f"Higher in females: {higher_in_f}")
# Out:
# Total significant transcripts: 5227
# Higher in males: 3399
# Higher in females: 1828

# %% [markdown]
# Significant genes

# %%
sig_genes = results_full_annot[results_full_annot["significant"]]

sig_genes
# Out:
#          baseMean  log2FoldChange     lfcSE       stat         pvalue  \
# 2        9.277403        1.333546  0.216804   6.150915   7.703709e-10
# 8      503.721255       -1.340457  0.071800 -18.669362   8.789681e-78
# 21      27.548224        4.055712  0.244114  16.613990   5.519643e-62
# 23      93.999016        2.475232  0.164587  15.039056   4.073171e-51
# 26     162.132955       -2.926584  0.137152 -21.338303  5.007964e-101
# ...           ...             ...       ...        ...            ...
# 14473  668.524089       -1.442250  0.051744 -27.872674  5.722264e-171
# 14481    4.662543        1.187264  0.328703   3.611970   3.038802e-04
# 14483    4.499280        1.464463  0.488840   2.995789   2.737353e-03
# 14486    3.644762        1.053781  0.354595   2.971785   2.960737e-03
# 14487   65.202446        1.386473  0.283779   4.885748   1.030367e-06
#
#                 padj transcript_id gene_id     seqname     start  ...  \
# 2       1.663951e-09     g10001.t1  g10001  utg000074l   8915422  ...
# 8       1.335129e-76      g1003.t1   g1003  utg000005l   5141771  ...
# 21      5.846867e-61     g10059.t1  g10059  utg000074l   9899121  ...
# 23      3.306684e-50     g10060.t1  g10060  utg000074l   9916445  ...
# 26      1.282163e-99     g10064.t1  g10064  utg000074l  10028082  ...
# ...              ...           ...     ...         ...       ...  ...
# 14473  6.796830e-169       g987.t1    g987  utg000005l   4473252  ...
# 14481   4.734467e-04      g9923.t1   g9923  utg000074l   8112428  ...
# 14483   3.934046e-03      g9934.t1   g9934  utg000074l   8241409  ...
# 14486   4.238691e-03      g9975.t1   g9975  utg000074l   8597833  ...
# 14487   1.889289e-06       g998.t1    g998  utg000005l   4824834  ...
#
#                                                      GOs   EC  \
# 2                                                      -    -
# 8      GO:0000976,GO:0000977,GO:0001012,GO:0001067,GO...    -
# 21                                                     -    -
# 23                                                     -    -
# 26     GO:0000228,GO:0000811,GO:0005575,GO:0005622,GO...    -
# ...                                                  ...  ...
# 14473  GO:0000003,GO:0000288,GO:0000290,GO:0000291,GO...    -
# 14481                                                  -    -
# 14483                                                  -    -
# 14486                                                NaN  NaN
# 14487                                                  -    -
#
#                    KEGG_ko      KEGG_Pathway COG_category  \
# 2                        -                 -            B
# 8      ko:K09228,ko:K09229                 -            J
# 21                       -                 -            -
# 23                       -                 -            -
# 26               ko:K10734                 -            L
# ...                    ...               ...          ...
# 14473            ko:K12611  ko03018,map03018           AK
# 14481                    -                 -            K
# 14483                    -                 -            S
# 14486                  NaN               NaN          NaN
# 14487                    -                 -            S
#
#                                               eggNOG_OGs      padj_safe  \
# 2                  KOG4585@1|root,KOG4585@2759|Eukaryota   1.663951e-09
# 8      KOG1721@1|root,KOG1721@2759|Eukaryota,38BZ9@33...   1.335129e-76
# 21     2CMJZ@1|root,2QQM3@2759|Eukaryota,39MCP@33154|...   5.846867e-61
# 23     2CMJZ@1|root,2QQM3@2759|Eukaryota,39MCP@33154|...   3.306684e-50
# 26     COG5138@1|root,KOG1106@2759|Eukaryota,393IP@33...   1.282163e-99
# ...                                                  ...            ...
# 14473  KOG2868@1|root,KOG2868@2759|Eukaryota,39W17@33...  6.796830e-169
# 14481  2DZH1@1|root,2S711@2759|Eukaryota,3A8F0@33154|...   4.734467e-04
# 14483  2EV8V@1|root,2SX9Q@2759|Eukaryota,3ASV5@33154|...   3.934046e-03
# 14486                                                NaN   4.238691e-03
# 14487  KOG1075@1|root,KOG1075@2759|Eukaryota,3A0JU@33...   1.889289e-06
#
#       neglog10_padj significant      label
# 2          8.778860        True  g10001.t1
# 8         75.874477        True   g1003.t1
# 21        60.233077        True  g10059.t1
# 23        49.480607        True  g10060.t1
# 26        98.892057        True  g10064.t1
# ...             ...         ...        ...
# 14473    168.167694        True    g987.t1
# 14481      3.324729        True   g9923.t1
# 14483      2.405161        True   g9934.t1
# 14486      2.372768        True   g9975.t1
# 14487      5.723702        True    g998.t1
#
# [5227 rows x 28 columns]
